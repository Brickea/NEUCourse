# %% [markdown]
# <div style="text-align: right">INFO 6105 Data Science Eng Methods and Tools, Lecture 7 Day 2</div>
# <div style="text-align: right">Dino Konstantopoulos, 14 October 2019</div>
#
# Instead of doing something new today, I decided I would help you on your homework :-)
#
# What happens if you can't get your hands on a dataset, and you need to scrape data from a web site? This notebook teaches you how to do it.
#
# # Bayesian Baseball analytics
#
# I found this beautiful baseball results Web site, [fangraphs](https://www.fangraphs.com/). Let's scape some data (probably better to use the Tom Brady sport analytics package, tho).
#
# I will concentrate on **attack** and **defense** as independent parameters. **Batting** for attack, and I will neglect **Fielding** in defense and concentrate solely on **pitching**. This is not good, but i'm professor, so I can do that (you can't).
#
# </br >
# <center>
# <img src="ipynb.images/calvin-grin.jpg" width=200 />
# </center>
#
# I also ***won't*** consider *all* players on the team, there's ***too many of them***. Moreover, many players remain on the bench and some (like pitchers) are on a rotation and play only every 5 games or so.

# %% [markdown]
# # Getting the data

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# Scraping Web pages with `Beautiful soup`:

# %%
def get_soup_team_pitching(season):
    url = "https://www.fangraphs.com/leaders.aspx?pos=all&stats=pit&lg=all&qual=0&type=8&season=2019&month=0&season1=" + str(season) + "&ind=0&team=0,ts&rost=0&age=0&filter=&players=0"
    s=requests.get(url).content
    #print(s)
    return BeautifulSoup(s, "lxml")

# %%
def get_soup_team_batting(season):
    url = "https://www.fangraphs.com/leaders.aspx?pos=all&stats=bat&lg=all&qual=0&type=8&season=2019&month=0&season1=" + str(season) + "&ind=0&team=0,ts&rost=0&age=0&filter=&players=0&startdate=&enddate="
    s=requests.get(url).content
    #print(s)
    return BeautifulSoup(s, "lxml")

# %%
def get_soup_players_pitching(season):
    url = "https://www.fangraphs.com/leaders.aspx?pos=all&stats=pit&lg=all&qual=y&type=8&season=2019&month=0&season1=" + str(season) + "&ind=0&team=0&rost=0&age=0&filter=&players=0&startdate=&enddate="
    s=requests.get(url).content
    #print(s)
    return BeautifulSoup(s, "lxml")

# %%
def get_soup_players_batting(season):
    url = "https://www.fangraphs.com/leaders.aspx?pos=all&stats=bat&lg=all&qual=y&type=8&season=2019&month=0&season1=" + str(season) + "&ind=0&team=0&rost=0&age=0&filter=&players=0&startdate=&enddate="
    s=requests.get(url).content
    #print(s)
    return BeautifulSoup(s, "lxml")

# %% [markdown]
# Finding the tables. First, some exploratory work:

# %%
get_soup_players_batting(2019).find_all('table')[1]

# %% [markdown]
# Ok, let's code!

# %%
def get_table_pitching(soup, team = True):

    numtables = get_num_tables_pitching(2019)
    
    tables = soup.find_all('table')
    table = tables[12]
    data = []
    # couldn't find these in the table, hardcoding for now
    if team:
        headings = ["Team", "W","L","SV","G","GS","IP","SO","K/9","BB/9","HR/9","BABIP","LOB%","GB%","HR/FB","ERA","FIP","xFIP","WAR"]
    else:
        headings = ["Name","Team","W","L","SV","G","GS","IP","SO","K/9","BB/9","HR/9","BABIP","LOB%","GB%","HR/FB","ERA","FIP","xFIP","WAR"]

    data.append(headings)
    table_body = table.find('tbody')
    rows = table_body.find_all('tr')
    for row in rows:
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        data.append([ele for ele in cols[1:]])
    data = pd.DataFrame(data)
    data = data.rename(columns=data.iloc[0])
    data = data.reindex(data.index.drop(0))
    return data

# %%
def get_table_batting(soup, team = True):

    tables = soup.find_all('table')
    table = tables[12]
    data = []
    # couldn't find these in the table, hardcoding for now
    if team:
        headings = ["Team", "G","PA","HR","R","RBI","SB","BB%","K%","ISO","BABIP","AVG","OBP","SLG","wOBA","wRC+","BsR","Off", "Def", "WAR"]
    else:
        headings = ["Name","Team", "G","PA","HR","R","RBI","SB","BB%","K%","ISO","BABIP","AVG","OBP","SLG","wOBA","wRC+","BsR","Off", "Def", "WAR"]

    data.append(headings)
    table_body = table.find('tbody')
    rows = table_body.find_all('tr')
    for row in rows:
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        data.append([ele for ele in cols[1:]])
    data = pd.DataFrame(data)
    data = data.rename(columns=data.iloc[0])
    data = data.reindex(data.index.drop(0))
    return data

# %% [markdown]
# Getting the pandas dataframes:

# %%
teams_pitching = get_table_pitching(get_soup_team_pitching(2019))
teams_pitching.head()
# Out:
#         Team    W   L  SV    G   GS      IP     SO   K/9  BB/9  HR/9   BABIP  \
# 1       Rays   96  66  46  765  162  1474.1   9.90  2.77  1.10  .290  73.8 %
# 2    Dodgers  106  56  44  707  162  1445.2   9.46  2.44  1.15  .271  74.7 %
# 3      Twins  101  61  50  686  162  1463.1   9.00  2.78  1.22  .309  71.8 %
# 4     Astros  107  55  47  654  162  1462.1  10.28  2.76  1.42  .270  76.8 %
# 5  Nationals   93  69  40  692  162  1439.1   9.45  3.23  1.26  .296  73.0 %
#
#      LOB%     GB% HR/FB   ERA   FIP  xFIP   WAR
# 1  44.1 %  13.4 %  3.67  3.65  3.89  25.3  None
# 2  44.9 %  14.1 %  3.39  3.73  3.87  24.1  None
# 3  41.8 %  13.4 %  4.18  4.03  4.27  23.9  None
# 4  43.6 %  16.7 %  3.66  3.98  3.80  23.7  None
# 5  42.6 %  13.9 %  4.28  4.14  4.32  22.3  None

# %%
teams_batting = get_table_batting(get_soup_team_batting(2019))
teams_batting.head()
# Out:
#         Team     G    PA   HR    R  RBI  SB     BB%      K%   ISO BABIP   AVG  \
# 1     Astros  2309  6394  288  920  891  67  10.1 %  18.2 %  .221  .296  .274
# 2    Dodgers  2413  6281  279  886  861  57   9.7 %  21.6 %  .215  .291  .257
# 3    Yankees  2312  6245  306  943  904  55   9.1 %  23.0 %  .222  .306  .267
# 4      Twins  2320  6392  307  939  906  28   8.2 %  20.9 %  .224  .300  .270
# 5  Athletics  2363  6269  257  845  800  49   9.2 %  21.3 %  .199  .282  .249
#
#     OBP   SLG  wOBA wRC+   BsR    Off    Def   WAR
# 1  .352  .495  .355  125  -9.5  196.6   -2.5  40.8
# 2  .338  .472  .338  111  11.9  102.9   51.7  34.8
# 3  .339  .490  .346  117  -0.8  130.8  -14.5  32.7
# 4  .338  .494  .347  116  -8.4  120.2  -26.7  31.0
# 5  .327  .448  .327  107  -1.7   53.4   18.3  28.5

# %% [markdown]
# Go [here](https://www.baseball-reference.com/bullpen/Baseball_statistics) for an explanation of each of the columns.

# %%
players_pitching = get_table_pitching(get_soup_players_pitching(2019), team = False)
players_pitching.head()
# Out:
#                Name       Team   W   L SV   G  GS     IP     SO   K/9  BB/9  \
# 1       Gerrit Cole     Astros  20   5  0  33  33  212.1  13.82  2.03  1.23
# 2      Jacob deGrom       Mets  11   8  0  32  32  204.0  11.25  1.94  0.84
# 3        Lance Lynn    Rangers  16  11  0  33  33  208.1  10.63  2.55  0.91
# 4      Max Scherzer  Nationals  11   7  0  27  27  172.1  12.69  1.72  0.94
# 5  Justin Verlander     Astros  21   6  0  34  34  223.0  12.11  1.70  1.45
#
#    HR/9   BABIP    LOB%     GB% HR/FB   ERA   FIP xFIP   WAR
# 1  .275  83.3 %  40.3 %  16.9 %  2.50  2.64  2.48  7.4  None
# 2  .282  81.8 %  44.4 %  11.2 %  2.43  2.67  3.11  7.0  None
# 3  .322  74.4 %  40.3 %   9.9 %  3.67  3.13  3.85  6.8  None
# 4  .321  78.7 %  40.8 %  11.6 %  2.92  2.45  2.88  6.5  None
# 5  .218  88.4 %  35.9 %  16.0 %  2.58  3.27  3.18  6.4  None

# %%
players_batting = get_table_batting(get_soup_players_batting(2019), team = False)
players_batting.head()
# Out:
#                Name       Team    G   PA  HR    R  RBI  SB     BB%      K%  \
# 1        Mike Trout     Angels  134  600  45  110  104  11  18.3 %  20.0 %
# 2      Alex Bregman     Astros  156  690  41  122  112   5  17.2 %  12.0 %
# 3  Christian Yelich    Brewers  130  580  44  100   97  30  13.8 %  20.3 %
# 4    Cody Bellinger    Dodgers  156  660  47  121  115  15  14.4 %  16.4 %
# 5     Marcus Semien  Athletics  162  747  33  123   92  10  11.6 %  13.7 %
#
#    ... BABIP   AVG   OBP   SLG  wOBA wRC+   BsR   Off   Def  WAR
# 1  ...  .298  .291  .438  .645  .436  180   7.1  68.2  -0.3  8.6
# 2  ...  .281  .296  .423  .592  .418  168  -2.1  58.2   4.8  8.5
# 3  ...  .355  .329  .429  .671  .442  174   8.5  65.2  -3.9  7.8
# 4  ...  .302  .305  .406  .629  .415  162   1.4  55.3   3.4  7.8
# 5  ...  .294  .285  .369  .522  .373  137   1.7  37.5  14.1  7.6
#
# [5 rows x 21 columns]

# %%
num_teams = len(teams_batting)
num_teams
# Out:
# 30

# %%
num_batters = len(players_batting)
num_batters
# Out:
# 30

# %%
num_pitchers = len(players_pitching)
num_pitchers
# Out:
# 30

# %% [markdown]
# What's wrong with ***these*** results?

# %% [markdown]
# <div style="display:none;">
# The number of pitchers and the number of batters ***equals*** the number of teams! How is ***that*** possible?!
# </div>

# %% [markdown]
# ### Python regexes

# %%
import re
txt = "The rain in Spain"
x = re.search("^The.*Spain$", txt)
x

# %%
txt = get_soup_players_batting(2019).find_all('table')[12]
txt
# Out:
# <table class="rgMasterTable" id="LeaderBoard1_dg1_ctl00" style="table-layout:auto;empty-cells:show;" width="100%">
# <colgroup>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# <col/>
# </colgroup>
# <thead>
# <tr class="rgPager">
# <td class="rgPagerCell" colspan="22"><div class="NextPrevAndNumeric rgSEO">
# <div class="rgWrap rgArrPart1">
# <a class="t-button rgActionButton rgPageFirst" title="First Page"><span class="t-font-icon rgIcon"></span></a><a class="t-button rgActionButton rgPagePrev" title="Previous Page"><span class="t-font-icon rgIcon"></span></a>
# </div><div class="rgWrap rgNumPart">
# <a class="rgCurrentPage" href="javascript:__doPostBack('LeaderBoard1$dg1$ctl00$ctl02$ctl00$ctl07','')" onclick="return false;">1</a><a href="/leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=&amp;enddate=&amp;page=2_30">2</a><a href="/leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=&amp;enddate=&amp;page=3_30">3</a><a href="/leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=&amp;enddate=&amp;page=4_30">4</a><a href="/leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=&amp;enddate=&amp;page=5_30">5</a>
# </div><div class="rgWrap rgArrPart2">
# <a class="t-button rgActionButton rgPageNext" href="/leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=&amp;enddate=&amp;page=2_30" title="Next Page"><span class="t-font-icon rgIcon"></span></a><a class="t-button rgActionButton rgPageLast" href="/leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=&amp;enddate=&amp;page=5_30" title="Last Page"><span class="t-font-icon rgIcon"></span></a>
# </div><div class="rgWrap rgAdvPart">
# <span class="rgPagerLabel" id="LeaderBoard1_dg1_ctl00_ctl02_ctl00_ChangePageSizeLabel">Page size:</span><div class="RadComboBox RadComboBox_FanGraphs" id="LeaderBoard1_dg1_ctl00_ctl02_ctl00_PageSizeComboBox">
# <span class="rcbInner rcbReadOnly"><input class="rcbInput radPreventDecorate" id="LeaderBoard1_dg1_ctl00_ctl02_ctl00_PageSizeComboBox_Input" name="LeaderBoard1$dg1$ctl00$ctl02$ctl00$PageSizeComboBox" readonly="readonly" type="text" value="30"/><button class="rcbActionButton" tabindex="-1" type="button"><span class="t-font-icon t-i-arrow-down" id="LeaderBoard1_dg1_ctl00_ctl02_ctl00_PageSizeComboBox_Arrow"></span><span class="rcbButtonText">select</span></button></span><div class="rcbSlide" style="z-index:6000;display:none;"><div class="RadComboBoxDropDown RadComboBoxDropDown_FanGraphs " id="LeaderBoard1_dg1_ctl00_ctl02_ctl00_PageSizeComboBox_DropDown"><div class="rcbScroll rcbWidth"><ul class="rcbList"><li class="rcbItem">10</li><li class="rcbItem">20</li><li class="rcbItem">30</li><li class="rcbItem">50</li></ul></div></div></div><input id="LeaderBoard1_dg1_ctl00_ctl02_ctl00_PageSizeComboBox_ClientState" name="LeaderBoard1_dg1_ctl00_ctl02_ctl00_PageSizeComboBox_ClientState" type="hidden"/>
# </div>
# </div><div class="rgWrap rgInfoPart">
# 					  <strong>135</strong> items in <strong>5</strong> pages
# 				</div>
# </div></td>
# </tr><tr>
# <th class="rgHeader" scope="col" style="text-align:right;">#</th><th class="rgHeader" scope="col"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=2019-01-01&amp;enddate=2019-12-31&amp;sort=1,d">Name</a></th><th class="rgHeader" scope="col"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=2019-01-01&amp;enddate=2019-12-31&amp;sort=2,d">Team</a></th><th class="rgHeader" scope="col" style="text-align:right;"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=2019-01-01&amp;enddate=2019-12-31&amp;sort=3,d">G</a></th><th class="rgHeader" scope="col" style="text-align:right;"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=2019-01-01&amp;enddate=2019-12-31&amp;sort=4,d">PA</a></th><th class="rgHeader" scope="col" style="text-align:right;"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=2019-01-01&amp;enddate=2019-12-31&amp;sort=5,d">HR</a></th><th class="rgHeader" scope="col" style="text-align:right;"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=2019-01-01&amp;enddate=2019-12-31&amp;sort=6,d">R</a></th><th class="rgHeader" scope="col" style="text-align:right;"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=2019-01-01&amp;enddate=2019-12-31&amp;sort=7,d">RBI</a></th><th class="rgHeader" scope="col" style="text-align:right;"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=2019-01-01&amp;enddate=2019-12-31&amp;sort=8,d">SB</a></th><th class="grid_line_breakh rgHeader" scope="col" style="text-align:right;"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=2019-01-01&amp;enddate=2019-12-31&amp;sort=9,d">BB%</a></th><th class="rgHeader" scope="col" style="text-align:right;"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=2019-01-01&amp;enddate=2019-12-31&amp;sort=10,d">K%</a></th><th class="rgHeader" scope="col" style="text-align:right;"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=2019-01-01&amp;enddate=2019-12-31&amp;sort=11,d">ISO</a></th><th class="rgHeader" scope="col" style="text-align:right;"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=2019-01-01&amp;enddate=2019-12-31&amp;sort=12,d">BABIP</a></th><th class="grid_line_breakh rgHeader" scope="col" style="text-align:right;"><a href="leaders.as ...
# </tr>
# </thead><tfoot>
# <tr class="rgPager">
# <td class="rgPagerCell" colspan="22"><div class="NextPrevAndNumeric rgSEO">
# <div class="rgWrap rgArrPart1">
# <a class="t-button rgActionButton rgPageFirst" title="First Page"><span class="t-font-icon rgIcon"></span></a><a class="t-button rgActionButton rgPagePrev" title="Previous Page"><span class="t-font-icon rgIcon"></span></a>
# </div><div class="rgWrap rgNumPart">
# <a class="rgCurrentPage" href="javascript:__doPostBack('LeaderBoard1$dg1$ctl00$ctl03$ctl01$ctl07','')" onclick="return false;">1</a><a href="/leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=&amp;enddate=&amp;page=2_30">2</a><a href="/leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=&amp;enddate=&amp;page=3_30">3</a><a href="/leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=&amp;enddate=&amp;page=4_30">4</a><a href="/leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=&amp;enddate=&amp;page=5_30">5</a>
# </div><div class="rgWrap rgArrPart2">
# <a class="t-button rgActionButton rgPageNext" href="/leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=&amp;enddate=&amp;page=2_30" title="Next Page"><span class="t-font-icon rgIcon"></span></a><a class="t-button rgActionButton rgPageLast" href="/leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=y&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=0&amp;rost=0&amp;age=0&amp;filter=&amp;players=0&amp;startdate=&amp;enddate=&amp;page=5_30" title="Last Page"><span class="t-font-icon rgIcon"></span></a>
# </div><div class="rgWrap rgAdvPart">
# <span class="rgPagerLabel" id="LeaderBoard1_dg1_ctl00_ctl03_ctl01_ChangePageSizeLabel">Page size:</span><div class="RadComboBox RadComboBox_FanGraphs" id="LeaderBoard1_dg1_ctl00_ctl03_ctl01_PageSizeComboBox">
# <span class="rcbInner rcbReadOnly"><input class="rcbInput radPreventDecorate" id="LeaderBoard1_dg1_ctl00_ctl03_ctl01_PageSizeComboBox_Input" name="LeaderBoard1$dg1$ctl00$ctl03$ctl01$PageSizeComboBox" readonly="readonly" type="text" value="30"/><button class="rcbActionButton" tabindex="-1" type="button"><span class="t-font-icon t-i-arrow-down" id="LeaderBoard1_dg1_ctl00_ctl03_ctl01_PageSizeComboBox_Arrow"></span><span class="rcbButtonText">select</span></button></span><div class="rcbSlide" style="z-index:6000;display:none;"><div class="RadComboBoxDropDown RadComboBoxDropDown_FanGraphs " id="LeaderBoard1_dg1_ctl00_ctl03_ctl01_PageSizeComboBox_DropDown"><div class="rcbScroll rcbWidth"><ul class="rcbList"><li class="rcbItem">10</li><li class="rcbItem">20</li><li class="rcbItem">30</li><li class="rcbItem">50</li></ul></div></div></div><input id="LeaderBoard1_dg1_ctl00_ctl03_ctl01_PageSizeComboBox_ClientState" name="LeaderBoard1_dg1_ctl00_ctl03_ctl01_PageSizeComboBox_ClientState" type="hidden"/>
# </div>
# </div><div class="rgWrap rgInfoPart">
# 					  <strong>135</strong> items in <strong>5</strong> pages
# 				</div>
# </div></td>
# </tr>
# </tfoot><tbody>
# <tr class="rgRow" id="LeaderBoard1_dg1_ctl00__0">
# <td align="right" class="grid_line_regular">1</td><td class="grid_line_regular"><a href="statss.aspx?playerid=10155&amp;position=OF">Mike Trout</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=1&amp;rost=0&amp;age=0">Angels</a></td><td align="right" class="grid_line_regular">134</td><td align="right" class="grid_line_regular">600</td><td align="right" class="grid_line_regular">45</td><td align="right" class="grid_line_regular">110</td><td align="right" class="grid_line_regular">104</td><td align="right" class="grid_line_regular">11</td><td align="right" class="grid_line_break">18.3 %</td><td align="right" class="grid_line_regular">20.0 %</td><td align="right" class="grid_line_regular">.353</td><td align="right" class="grid_line_regular">.298</td><td align="right" class="grid_line_break">.291</td><td align="right" class="grid_line_regular">.438</td><td align="right" class="grid_line_regular">.645</td><td align="right" class="grid_line_regular">.436</td><td align="right" class="grid_line_regular">180</td><td align="right" class="grid_line_break">7.1</td><td align="right" class="grid_line_break">68.2</td><td align="right" class="grid_line_regular">-0.3</td><td align="right" class="grid_line_regular">8.6</td>
# </tr><tr class="rgAltRow" id="LeaderBoard1_dg1_ctl00__1">
# <td align="right" class="grid_line_regular">2</td><td class="grid_line_regular"><a href="statss.aspx?playerid=17678&amp;position=3B">Alex Bregman</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=21&amp;rost=0&amp;age=0">Astros</a></td><td align="right" class="grid_line_regular">156</td><td align="right" class="grid_line_regular">690</td><td align="right" class="grid_line_regular">41</td><td align="right" class="grid_line_regular">122</td><td align="right" class="grid_line_regular">112</td><td align="right" class="grid_line_regular">5</td><td align="right" class="grid_line_break">17.2 %</td><td align="right" class="grid_line_regular">12.0 %</td><td align="right" class="grid_line_regular">.296</td><td align="right" class="grid_line_regular">.281</td><td align="right" class="grid_line_break">.296</td><td align="right" class="grid_line_regular">.423</td><td align="right" class="grid_line_regular">.592</td><td align="right" class="grid_line_regular">.418</td><td align="right" class="grid_line_regular">168</td><td align="right" class="grid_line_break">-2.1</td><td align="right" class="grid_line_break">58.2</td><td align="right" class="grid_line_regular">4.8</td><td align="right" class="grid_line_regular">8.5</td>
# </tr><tr class="rgRow" id="LeaderBoard1_dg1_ctl00__2">
# <td align="right" class="grid_line_regular">3</td><td class="grid_line_regular"><a href="statss.aspx?playerid=11477&amp;position=OF">Christian Yelich</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=23&amp;rost=0&amp;age=0">Brewers</a></td><td align="right" class="grid_line_regular">130</td><td align="right" class="grid_line_regular">580</td><td align="right" class="grid_line_regular">44</td><td align="right" class="grid_line_regular">100</td><td align="right" class="grid_line_regular">97</td><td align="right" class="grid_line_regular">30</td><td align="right" class="grid_line_break">13.8 %</td><td align="right" class="grid_line_regular">20.3 %</td><td align="right" class="grid_line_regular">.342</td><td align="right" class="grid_line_regular">.355</td><td align="right" class="grid_line_break">.329</td><td align="right" class="grid_line_regular">.429</td><td align="right" class="grid_line_regular">.671</td><td align="right" class="grid_line_regular">.442</td><td align="right" class="grid_line_regular">174</td><td align="right" class="grid_line_break">8.5</td><td align="right" class="grid_line_break">65.2</td><td align="right" class="grid_line_regular">-3.9</td><td align="right" class="grid_line_regular">7.8</td>
# </tr><tr class="rgAltRow" id="LeaderBoard1_dg1_ctl00__3">
# <td align="right" class="grid_line_regular">4</td><td class="grid_line_regular"><a href="statss.aspx?playerid=15998&amp;position=1B/OF">Cody Bellinger</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=22&amp;rost=0&amp;age=0">Dodgers</a></td><td align="right" class="grid_line_regular">156</td><td align="right" class="grid_line_regular">660</td><td align="right" class="grid_line_regular">47</td><td align="right" class="grid_line_regular">121</td><td align="right" class="grid_line_regular">115</td><td align="right" class="grid_line_regular">15</td><td align="right" class="grid_line_break">14.4 %</td><td align="right" class="grid_line_regular">16.4 %</td><td align="right" class="grid_line_regular">.324</td><td align="right" class="grid_line_regular">.302</td><td align="right" class="grid_line_break">.305</td><td align="right" class="grid_line_regular">.406</td><td align="right" class="grid_line_regular">.629</td><td align="right" class="grid_line_regular">.415</td><td align="right" class="grid_line_regular">162</td><td align="right" class="grid_line_break">1.4</td><td align="right" class="grid_line_break">55.3</td><td align="right" class="grid_line_regular">3.4</td><td align="right" class="grid_line_regular">7.8</td>
# </tr><tr class="rgRow" id="LeaderBoard1_dg1_ctl00__4">
# <td align="right" class="grid_line_regular">5</td><td class="grid_line_regular"><a href="statss.aspx?playerid=12533&amp;position=SS">Marcus Semien</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=10&amp;rost=0&amp;age=0">Athletics</a></td><td align="right" class="grid_line_regular">162</td><td align="right" class="grid_line_regular">747</td><td align="right" class="grid_line_regular">33</td><td align="right" class="grid_line_regular">123</td><td align="right" class="grid_line_regular">92</td><td align="right" class="grid_line_regular">10</td><td align="right" class="grid_line_break">11.6 %</td><td align="right" class="grid_line_regular">13.7 %</td><td align="right" class="grid_line_regular">.237</td><td align="right" class="grid_line_regular">.294</td><td align="right" class="grid_line_break">.285</td><td align="right" class="grid_line_regular">.369</td><td align="right" class="grid_line_regular">.522</td><td align="right" class="grid_line_regular">.373</td><td align="right" class="grid_line_regular">137</td><td align="right" class="grid_line_break">1.7</td><td align="right" class="grid_line_break">37.5</td><td align="right" class="grid_line_regular">14.1</td><td align="right" class="grid_line_regular">7.6</td>
# </tr><tr class="rgAltRow" id="LeaderBoard1_dg1_ctl00__5">
# <td align="right" class="grid_line_regular">6</td><td class="grid_line_regular"><a href="statss.aspx?playerid=13613&amp;position=2B/SS">Ketel Marte</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=15&amp;rost=0&amp;age=0">Diamondbacks</a></td><td align="right" class="grid_line_regular">144</td><td align="right" class="grid_line_regular">628</td><td align="right" class="grid_line_regular">32</td><td align="right" class="grid_line_regular">97</td><td align="right" class="grid_line_regular">92</td><td align="right" class="grid_line_regular">10</td><td align="right" class="grid_line_break">8.4 %</td><td align="right" class="grid_line_regular">13.7 %</td><td align="right" class="grid_line_regular">.264</td><td align="right" class="grid_line_regular">.342</td><td align="right" class="grid_line_break">.329</td><td align="right" class="grid_line_regular">.389</td><td align="right" class="grid_line_regular">.592</td><td align="right" class="grid_line_regular">.405</td><td align="right" class="grid_line_regular">150</td><td align="right" class="grid_line_break">4.2</td><td align="right" class="grid_line_break">46.0</td><td align="right" class="grid_line_regular">6.7</td><td align="right" class="grid_line_regular">7.1</td>
# </tr><tr class="rgRow" id="LeaderBoard1_dg1_ctl00__6">
# <td align="right" class="grid_line_regular">7</td><td class="grid_line_regular"><a href="statss.aspx?playerid=12861&amp;position=3B">Anthony Rendon</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=24&amp;rost=0&amp;age=0">Nationals</a></td><td align="right" class="grid_line_regular">146</td><td align="right" class="grid_line_regular">646</td><td align="right" class="grid_line_regular">34</td><td align="right" class="grid_line_regular">117</td><td align="right" class="grid_line_regular">126</td><td align="right" class="grid_line_regular">5</td><td align="right" class="grid_line_break">12.4 %</td><td align="right" class="grid_line_regular">13.3 %</td><td align="right" class="grid_line_regular">.279</td><td align="right" class="grid_line_regular">.323</td><td align="right" class="grid_line_break">.319</td><td align="right" class="grid_line_regular">.412</td><td align="right" class="grid_line_regular">.598</td><td align="right" class="grid_line_regular">.413</td><td align="right" class="grid_line_regular">154</td><td align="right" class="grid_line_break">0.4</td><td align="right" class="grid_line_break">46.5</td><td align="right" class="grid_line_regular">4.2</td><td align="right" class="grid_line_regular">7.0</td>
# </tr><tr class="rgAltRow" id="LeaderBoard1_dg1_ctl00__7">
# <td align="right" class="grid_line_regular">8</td><td class="grid_line_regular"><a href="statss.aspx?playerid=12161&amp;position=SS">Xander Bogaerts</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=3&amp;rost=0&amp;age=0">Red Sox</a></td><td align="right" class="grid_line_regular">155</td><td align="right" class="grid_line_regular">698</td><td align="right" class="grid_line_regular">33</td><td align="right" class="grid_line_regular">110</td><td align="right" class="grid_line_regular">117</td><td align="right" class="grid_line_regular">4</td><td align="right" class="grid_line_break">10.9 %</td><td align="right" class="grid_line_regular">17.5 %</td><td align="right" class="grid_line_regular">.246</td><td align="right" class="grid_line_regular">.338</td><td align="right" class="grid_line_break">.309</td><td align="right" class="grid_line_regular">.384</td><td align="right" class="grid_line_regular">.555</td><td align="right" class="grid_line_regular">.390</td><td align="right" class="grid_line_regular">141</td><td align="right" class="grid_line_break">1.0</td><td align="right" class="grid_line_break">37.6</td><td align="right" class="grid_line_regular">8.1</td><td align="right" class="grid_line_regular">6.8</td>
# </tr><tr class="rgRow" id="LeaderBoard1_dg1_ctl00__8">
# <td align="right" class="grid_line_regular">9</td><td class="grid_line_regular"><a href="statss.aspx?playerid=13611&amp;position=OF">Mookie Betts</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=3&amp;rost=0&amp;age=0">Red Sox</a></td><td align="right" class="grid_line_regular">150</td><td align="right" class="grid_line_regular">706</td><td align="right" class="grid_line_regular">29</td><td align="right" class="grid_line_regular">135</td><td align="right" class="grid_line_regular">80</td><td align="right" class="grid_line_regular">16</td><td align="right" class="grid_line_break">13.7 %</td><td align="right" class="grid_line_regular">14.3 %</td><td align="right" class="grid_line_regular">.229</td><td align="right" class="grid_line_regular">.309</td><td align="right" class="grid_line_break">.295</td><td align="right" class="grid_line_regular">.391</td><td align="right" class="grid_line_regular">.524</td><td align="right" class="grid_line_regular">.380</td><td align="right" class="grid_line_regular">135</td><td align="right" class="grid_line_break">5.6</td><td align="right" class="grid_line_break">37.0</td><td align="right" class="grid_line_regular">6.3</td><td align="right" class="grid_line_regular">6.6</td>
# </tr><tr class="rgAltRow" id="LeaderBoard1_dg1_ctl00__9">
# <td align="right" class="grid_line_regular">10</td><td class="grid_line_regular"><a href="statss.aspx?playerid=12856&amp;position=OF">George Springer</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=21&amp;rost=0&amp;age=0">Astros</a></td><td align="right" class="grid_line_regular">122</td><td align="right" class="grid_line_regular">556</td><td align="right" class="grid_line_regular">39</td><td align="right" class="grid_line_regular">96</td><td align="right" class="grid_line_regular">96</td><td align="right" class="grid_line_regular">6</td><td align="right" class="grid_line_break">12.1 %</td><td align="right" class="grid_line_regular">20.3 %</td><td align="right" class="grid_line_regular">.299</td><td align="right" class="grid_line_regular">.305</td><td align="right" class="grid_line_break">.292</td><td align="right" class="grid_line_regular">.383</td><td align="right" class="grid_line_regular">.591</td><td align="right" class="grid_line_regular">.400</td><td align="right" class="grid_line_regular">156</td><td align="right" class="grid_line_break">0.9</td><td align="right" class="grid_line_break">40.9</td><td align="right" class="grid_line_regular">6.4</td><td align="right" class="grid_line_regular">6.5</td>
# </tr><tr class="rgRow" id="LeaderBoard1_dg1_ctl00__10">
# <td align="right" class="grid_line_regular">11</td><td class="grid_line_regular"><a href="statss.aspx?playerid=16505&amp;position=3B">Matt Chapman</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=10&amp;rost=0&amp;age=0">Athletics</a></td><td align="right" class="grid_line_regular">156</td><td align="right" class="grid_line_regular">670</td><td align="right" class="grid_line_regular">36</td><td align="right" class="grid_line_regular">102</td><td align="right" class="grid_line_regular">91</td><td align="right" class="grid_line_regular">1</td><td align="right" class="grid_line_break">10.9 %</td><td align="right" class="grid_line_regular">21.9 %</td><td align="right" class="grid_line_regular">.257</td><td align="right" class="grid_line_regular">.270</td><td align="right" class="grid_line_break">.249</td><td align="right" class="grid_line_regular">.342</td><td align="right" class="grid_line_regular">.506</td><td align="right" class="grid_line_regular">.354</td><td align="right" class="grid_line_regular">125</td><td align="right" class="grid_line_break">0.9</td><td align="right" class="grid_line_break">22.4</td><td align="right" class="grid_line_regular">17.1</td><td align="right" class="grid_line_regular">6.1</td>
# </tr><tr class="rgAltRow" id="LeaderBoard1_dg1_ctl00__11">
# <td align="right" class="grid_line_regular">12</td><td class="grid_line_regular"><a href="statss.aspx?playerid=17350&amp;position=3B">Rafael Devers</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=3&amp;rost=0&amp;age=0">Red Sox</a></td><td align="right" class="grid_line_regular">156</td><td align="right" class="grid_line_regular">702</td><td align="right" class="grid_line_regular">32</td><td align="right" class="grid_line_regular">129</td><td align="right" class="grid_line_regular">115</td><td align="right" class="grid_line_regular">8</td><td align="right" class="grid_line_break">6.8 %</td><td align="right" class="grid_line_regular">17.0 %</td><td align="right" class="grid_line_regular">.244</td><td align="right" class="grid_line_regular">.339</td><td align="right" class="grid_line_break">.311</td><td align="right" class="grid_line_regular">.361</td><td align="right" class="grid_line_regular">.555</td><td align="right" class="grid_line_regular">.377</td><td align="right" class="grid_line_regular">132</td><td align="right" class="grid_line_break">2.3</td><td align="right" class="grid_line_break">31.4</td><td align="right" class="grid_line_regular">4.9</td><td align="right" class="grid_line_regular">5.9</td>
# </tr><tr class="rgRow" id="LeaderBoard1_dg1_ctl00__12">
# <td align="right" class="grid_line_regular">13</td><td class="grid_line_regular"><a href="statss.aspx?playerid=9777&amp;position=3B">Nolan Arenado</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=19&amp;rost=0&amp;age=0">Rockies</a></td><td align="right" class="grid_line_regular">155</td><td align="right" class="grid_line_regular">662</td><td align="right" class="grid_line_regular">41</td><td align="right" class="grid_line_regular">102</td><td align="right" class="grid_line_regular">118</td><td align="right" class="grid_line_regular">3</td><td align="right" class="grid_line_break">9.4 %</td><td align="right" class="grid_line_regular">14.0 %</td><td align="right" class="grid_line_regular">.269</td><td align="right" class="grid_line_regular">.312</td><td align="right" class="grid_line_break">.315</td><td align="right" class="grid_line_regular">.379</td><td align="right" class="grid_line_regular">.583</td><td align="right" class="grid_line_regular">.392</td><td align="right" class="grid_line_regular">128</td><td align="right" class="grid_line_break">2.5</td><td align="right" class="grid_line_break">27.1</td><td align="right" class="grid_line_regular">12.5</td><td align="right" class="grid_line_regular">5.9</td>
# </tr><tr class="rgAltRow" id="LeaderBoard1_dg1_ctl00__13">
# <td align="right" class="grid_line_regular">14</td><td class="grid_line_regular"><a href="statss.aspx?playerid=12564&amp;position=SS">Trevor Story</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=19&amp;rost=0&amp;age=0">Rockies</a></td><td align="right" class="grid_line_regular">145</td><td align="right" class="grid_line_regular">656</td><td align="right" class="grid_line_regular">35</td><td align="right" class="grid_line_regular">111</td><td align="right" class="grid_line_regular">85</td><td align="right" class="grid_line_regular">23</td><td align="right" class="grid_line_break">8.8 %</td><td align="right" class="grid_line_regular">26.5 %</td><td align="right" class="grid_line_regular">.260</td><td align="right" class="grid_line_regular">.361</td><td align="right" class="grid_line_break">.294</td><td align="right" class="grid_line_regular">.363</td><td align="right" class="grid_line_regular">.554</td><td align="right" class="grid_line_regular">.380</td><td align="right" class="grid_line_regular">121</td><td align="right" class="grid_line_break">5.9</td><td align="right" class="grid_line_break">23.8</td><td align="right" class="grid_line_regular">15.1</td><td align="right" class="grid_line_regular">5.8</td>
# </tr><tr class="rgRow" id="LeaderBoard1_dg1_ctl00
a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=25&amp;rost=0&amp;age=0">Mets</a></td><td align="right" class="grid_line_regular">161</td><td align="right" class="grid_line_regular">693</td><td align="right" class="grid_line_regular">53</td><td align="right" class="grid_line_regular">103</td><td align="right" class="grid_line_regular">120</td><td align="right" class="grid_line_regular">1</td><td align="right" class="grid_line_break">10.4 %</td><td align="right" class="grid_line_regular">26.4 %</td><td align="right" class="grid_line_regular">.323</td><td align="right" class="grid_line_regular">.280</td><td align="right" class="grid_line_break">.260</td><td align="right" class="grid_line_regular">.358</td><td align="right" class="grid_line_regular">.583</td><td align="right" class="grid_line_regular">.384</td><td align="right" class="grid_line_regular">143</td><td align="right" class="grid_line_break">-2.2</td><td align="right" class="grid_line_break">37.0</td><td align="right" class="grid_line_regular">-9.7</td><td align="right" class="grid_line_regular">4.8</td>
# </tr><tr class="rgAltRow" id="LeaderBoard1_dg1_ctl00__21">
# <td align="right" class="grid_line_regular">22</td><td class="grid_line_regular"><a href="statss.aspx?playerid=20123&amp;position=OF">Juan Soto</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=24&amp;rost=0&amp;age=0">Nationals</a></td><td align="right" class="grid_line_regular">150</td><td align="right" class="grid_line_regular">659</td><td align="right" class="grid_line_regular">34</td><td align="right" class="grid_line_regular">110</td><td align="right" class="grid_line_regular">110</td><td align="right" class="grid_line_regular">12</td><td align="right" class="grid_line_break">16.4 %</td><td align="right" class="grid_line_regular">20.0 %</td><td align="right" class="grid_line_regular">.266</td><td align="right" class="grid_line_regular">.312</td><td align="right" class="grid_line_break">.282</td><td align="right" class="grid_line_regular">.401</td><td align="right" class="grid_line_regular">.548</td><td align="right" class="grid_line_regular">.394</td><td align="right" class="grid_line_regular">142</td><td align="right" class="grid_line_break">-0.5</td><td align="right" class="grid_line_break">35.9</td><td align="right" class="grid_line_regular">-7.5</td><td align="right" class="grid_line_regular">4.8</td>
# </tr><tr class="rgRow" id="LeaderBoard1_dg1_ctl00__22">
# <td align="right" class="grid_line_regular">23</td><td class="grid_line_regular"><a href="statss.aspx?playerid=13301&amp;position=1B/2B">Max Muncy</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=22&amp;rost=0&amp;age=0">Dodgers</a></td><td align="right" class="grid_line_regular">141</td><td align="right" class="grid_line_regular">589</td><td align="right" class="grid_line_regular">35</td><td align="right" class="grid_line_regular">101</td><td align="right" class="grid_line_regular">98</td><td align="right" class="grid_line_regular">4</td><td align="right" class="grid_line_break">15.3 %</td><td align="right" class="grid_line_regular">25.3 %</td><td align="right" class="grid_line_regular">.265</td><td align="right" class="grid_line_regular">.283</td><td align="right" class="grid_line_break">.251</td><td align="right" class="grid_line_regular">.374</td><td align="right" class="grid_line_regular">.515</td><td align="right" class="grid_line_regular">.372</td><td align="right" class="grid_line_regular">134</td><td align="right" class="grid_line_break">4.8</td><td align="right" class="grid_line_break">31.3</td><td align="right" class="grid_line_regular">-0.8</td><td align="right" class="grid_line_regular">4.8</td>
# </tr><tr class="rgAltRow" id="LeaderBoard1_dg1_ctl00__23">
# <td align="right" class="grid_line_regular">24</td><td class="grid_line_regular"><a href="statss.aspx?playerid=15429&amp;position=3B">Kris Bryant</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=17&amp;rost=0&amp;age=0">Cubs</a></td><td align="right" class="grid_line_regular">147</td><td align="right" class="grid_line_regular">634</td><td align="right" class="grid_line_regular">31</td><td align="right" class="grid_line_regular">108</td><td align="right" class="grid_line_regular">77</td><td align="right" class="grid_line_regular">4</td><td align="right" class="grid_line_break">11.7 %</td><td align="right" class="grid_line_regular">22.9 %</td><td align="right" class="grid_line_regular">.239</td><td align="right" class="grid_line_regular">.331</td><td align="right" class="grid_line_break">.282</td><td align="right" class="grid_line_regular">.382</td><td align="right" class="grid_line_regular">.521</td><td align="right" class="grid_line_regular">.379</td><td align="right" class="grid_line_regular">135</td><td align="right" class="grid_line_break">3.8</td><td align="right" class="grid_line_break">32.9</td><td align="right" class="grid_line_regular">-4.1</td><td align="right" class="grid_line_regular">4.8</td>
# </tr><tr class="rgRow" id="LeaderBoard1_dg1_ctl00
td>
# </tr><tr class="rgAltRow" id="LeaderBoard1_dg1_ctl00__27">
# <td align="right" class="grid_line_regular">28</td><td class="grid_line_regular"><a href="statss.aspx?playerid=12552&amp;position=3B">Eugenio Suarez</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=18&amp;rost=0&amp;age=0">Reds</a></td><td align="right" class="grid_line_regular">159</td><td align="right" class="grid_line_regular">662</td><td align="right" class="grid_line_regular">49</td><td align="right" class="grid_line_regular">87</td><td align="right" class="grid_line_regular">103</td><td align="right" class="grid_line_regular">3</td><td align="right" class="grid_line_break">10.6 %</td><td align="right" class="grid_line_regular">28.5 %</td><td align="right" class="grid_line_regular">.301</td><td align="right" class="grid_line_regular">.312</td><td align="right" class="grid_line_break">.271</td><td align="right" class="grid_line_regular">.358</td><td align="right" class="grid_line_regular">.572</td><td align="right" class="grid_line_regular">.381</td><td align="right" class="grid_line_regular">133</td><td align="right" class="grid_line_break">-6.2</td><td align="right" class="grid_line_break">22.6</td><td align="right" class="grid_line_regular">1.9</td><td align="right" class="grid_line_regular">4.5</td>
# </tr><tr class="rgRow" id="LeaderBoard1_dg1_ctl00__28">
# <td align="right" class="grid_line_regular">29</td><td class="grid_line_regular"><a href="statss.aspx?playerid=12144&amp;position=OF">Max Kepler</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=8&amp;rost=0&amp;age=0">Twins</a></td><td align="right" class="grid_line_regular">134</td><td align="right" class="grid_line_regular">596</td><td align="right" class="grid_line_regular">36</td><td align="right" class="grid_line_regular">98</td><td align="right" class="grid_line_regular">90</td><td align="right" class="grid_line_regular">1</td><td align="right" class="grid_line_break">10.1 %</td><td align="right" class="grid_line_regular">16.6 %</td><td align="right" class="grid_line_regular">.267</td><td align="right" class="grid_line_regular">.244</td><td align="right" class="grid_line_break">.252</td><td align="right" class="grid_line_regular">.336</td><td align="right" class="grid_line_regular">.519</td><td align="right" class="grid_line_regular">.355</td><td align="right" class="grid_line_regular">121</td><td align="right" class="grid_line_break">-1.8</td><td align="right" class="grid_line_break">14.4</td><td align="right" class="grid_line_regular">10.0</td><td align="right" class="grid_line_regular">4.4</td>
# </tr><tr class="rgAltRow" id="LeaderBoard1_dg1_ctl00__29">
# <td align="right" class="grid_line_regular">30</td><td class="grid_line_regular"><a href="statss.aspx?playerid=12979&amp;position=2B/SS">Javier Baez</a></td><td class="grid_line_regular"><a href="leaders.aspx?pos=all&amp;stats=bat&amp;lg=all&amp;qual=0&amp;type=8&amp;season=2019&amp;month=0&amp;season1=2019&amp;ind=0&amp;team=17&amp;rost=0&amp;age=0">Cubs</a></td><td align="right" class="grid_line_regular">138</td><td align="right" class="grid_line_regular">561</td><td align="right" class="grid_line_regular">29</td><td align="right" class="grid_line_regular">89</td><td align="right" class="grid_line_regular">85</td><td align="right" class="grid_line_regular">11</td><td align="right" class="grid_line_break">5.0 %</td><td align="right" class="grid_line_regular">27.8 %</td><td align="right" class="grid_line_regular">.250</td><td align="right" class="grid_line_regular">.345</td><td align="right" class="grid_line_break">.281</td><td align="right" class="grid_line_regular">.316</td><td align="right" class="grid_line_regular">.531</td><td align="right" class="grid_line_regular">.347</td><td align="right" class="grid_line_regular">114</td><td align="right" class="grid_line_break">1.2</td><td align="right" class="grid_line_break">11.2</td><td align="right" class="grid_line_regular">15.7</td><td align="right" class="grid_line_regular">4.4</td>
# </tr>
# </tbody>
# </table>

# %%
x = re.search("\<strong\>.*\</strong\> items in \<strong\>.*\</strong\>", str(txt))
x
# Out:
# <_sre.SRE_Match object; span=(3799, 3847), match='<strong>135</strong> items in <strong>5</strong>'>

# %%
import re

# <strong>135</strong> items in <strong>5</strong> pages
txt = get_soup_players_batting(2019).find_all('table')[12]
#txt
x = re.search("\<strong\>.*\</strong\> items in \<strong\>.*\</strong\>", str(txt))
match = x.group()
start = match.find('>')
match = match[start:]
end = match.find('<')
print(match[1: end])

y = re.search("items in \<strong\>.*\</strong\>", x.group())
match = y.group()
start = match.find('>')
end = match.rfind('<')
start, end
print(int(match[start + 1: end]))

# %% [markdown]
# Putting this all together:

# %%
season = 2019
url = "https://www.fangraphs.com/leaders.aspx?pos=all&stats=pit&lg=all&qual=y&type=8&season=" + str(season) + "&month=0&season1=2019&ind=0&team=0&rost=0&age=0&filter=&players=0&startdate=&enddate="
perpage, pages = get_num_tables_players_pitching(2019)
perpage, pages

# %%
season = 2019
url = "https://www.fangraphs.com/leaders.aspx?pos=all&stats=pit&lg=all&qual=y&type=8&season=" + str(season) + "&month=0&season1=2019&ind=0&team=0&rost=0&age=0&filter=&players=0&startdate=&enddate="
perpage, pages = get_num_tables_players_pitching(2019)
print(str(perpage) + ", " + str(pages))
df_all = []

pd.set_option('display.max_rows', None)

for i in range(0, 4):
    url2 = url + "&page=" + str(i+5) + "_" + str(30)
    print(url2)
    s=requests.get(url2).content
    soup = BeautifulSoup(s, "lxml")
    df_all.append(get_table_pitching(soup, team = False))
    time.sleep(60)
newpd = pd.concat(df_all, ignore_index= True)
newpd

# %%
import re

def get_num_tables_players_pitching(season):
    txt = get_soup_players_pitching(season).find_all('table')[12]
    x = re.search("\<strong\>.*\</strong\> items in \<strong\>.*\</strong\>", str(txt))
    match = x.group()
    start = match.find('>')
    match = match[start:]
    end = match.find('<')
    perpage = int(match[1: end])

    y = re.search("items in \<strong\>.*\</strong\>", x.group())
    match = y.group()
    start = match.find('>')
    end = match.rfind('<')
    pages = int(match[start + 1: end])
    
    return perpage, pages

# %%
import re

def get_num_tables_players_batting(season):
    txt = get_soup_players_batting(season).find_all('table')[12]
    x = re.search("\<strong\>.*\</strong\> items in \<strong\>.*\</strong\>", str(txt))
    match = x.group()
    start = match.find('>')
    match = match[start:]
    end = match.find('<')
    perpage = int(match[1: end])
    
    y = re.search("items in \<strong\>.*\</strong\>", x.group())
    match = y.group()
    start = match.find('>')
    end = match.rfind('<')
    pages = int(match[start + 1: end])
    
    return perpage, pages

# %%
get_num_tables_players_pitching(2019)
# Out:
# (61, 3)

# %%
get_num_tables_players_batting(2019)
# Out:
# (135, 5)

# %% [markdown]
# The commented out part of the code is the right way of doing it, but `fangraphs` is throttling the Web site, so instead
# I found a hack to get most of the data.

# %%
def get_table_batting_2(season, team = True):

    if team:
        url = "https://www.fangraphs.com/leaders.aspx?pos=all&stats=bat&lg=all&qual=0&type=8&season=" + str(season) + "&month=0&season1=2019&ind=0&team=0,ts&rost=0&age=0&filter=&players=0&startdate=&enddate="
        s=requests.get(url).content
        soup = BeautifulSoup(s, "lxml")
        return get_table_batting(soup, team = True)
    
    else:
        #url = "https://www.fangraphs.com/leaders.aspx?pos=all&stats=bat&lg=all&qual=0&type=8&season=2019&month=0&season1=2019&ind=0&team=0&rost=0&age=0&filter=&players=0&startdate=&enddate="
        #perpage, pages = get_num_tables_players_pitching(2019)
        #df_all = []
        #for i in range(0, pages):
        #    url2 = ulr + "&page=" + str(i) + "_" + str(perpage)
        #    s=requests.get(url2).content
        #    soup = BeautifulSoup(s, "lxml")
        #    df_all.append(get_tables_batting(soup, team = False))
        #    time.sleep(60)
        #return pd.concat(df_all)
        
        url = "https://www.fangraphs.com/leaders.aspx?pos=all&stats=bat&lg=all&qual=y&type=8&season=" + str(season) + "&month=0&season1=2019&ind=0&team=0&rost=0&age=0&filter=&players=0&startdate=&enddate=&page=1_900"
        s=requests.get(url).content
        soup = BeautifulSoup(s, "lxml")
        return get_table_batting(soup, team = False)

# %%
import time

def get_table_pitching_2(season, team = True):

    if team:
        url = "https://www.fangraphs.com/leaders.aspx?pos=all&stats=pit&lg=all&qual=0&type=8&season=" + str(season) + "&month=0&season1=2019&ind=0&team=0,ts&rost=0&age=0&filter=&players=0&startdate=&enddate="
        s=requests.get(url).content
        soup = BeautifulSoup(s, "lxml")
        return get_table_pitching(soup, team = True)
    
    else:
        #url = "https://www.fangraphs.com/leaders.aspx?pos=all&stats=pit&lg=all&qual=y&type=8&season=" + str(season) + "&month=0&season1=2019&ind=0&team=0&rost=0&age=0&filter=&players=0&startdate=&enddate="
        #perpage, pages = get_num_tables_players_pitching(2019)
        #pages = 4
        #df_all = []
        #for i in range(0, pages):
        #    url2 = url + "&page=" + str(i) + "_" + str(perpage)
        #    s=requests.get(url2).content
        #    soup = BeautifulSoup(s, "lxml")
        #    df_all.append(get_tables_pitching(soup, team = False))
        #    time.sleep(60)
        #return pd.concat(df_all)
        
        url = "https://www.fangraphs.com/leaders.aspx?pos=all&stats=pit&lg=all&qual=y&type=8&season=" + str(season) + "&month=0&season1=2019&ind=0&team=0&rost=0&age=0&filter=&players=0&startdate=&enddate=&page=1_200"
        s=requests.get(url).content
        soup = BeautifulSoup(s, "lxml")
        return get_table_pitching(soup, team = False)

# %% [markdown]
# ## Better? Let's see
#
# Getting the `pandas` dataframes:

# %%
teams_pitching = get_table_pitching_2(2019, team = True)
teams_pitching.head()
# Out:
#         Team    W   L  SV    G   GS      IP     SO   K/9  BB/9  HR/9   BABIP  \
# 1       Rays   96  66  46  765  162  1474.1   9.90  2.77  1.10  .290  73.8 %
# 2    Dodgers  106  56  44  707  162  1445.2   9.46  2.44  1.15  .271  74.7 %
# 3      Twins  101  61  50  686  162  1463.1   9.00  2.78  1.22  .309  71.8 %
# 4     Astros  107  55  47  654  162  1462.1  10.28  2.76  1.42  .270  76.8 %
# 5  Nationals   93  69  40  692  162  1439.1   9.45  3.23  1.26  .296  73.0 %
#
#      LOB%     GB% HR/FB   ERA   FIP  xFIP   WAR
# 1  44.1 %  13.4 %  3.67  3.65  3.89  25.3  None
# 2  44.9 %  14.1 %  3.39  3.73  3.87  24.1  None
# 3  41.8 %  13.4 %  4.18  4.03  4.27  23.9  None
# 4  43.6 %  16.7 %  3.66  3.98  3.80  23.7  None
# 5  42.6 %  13.9 %  4.28  4.14  4.32  22.3  None

# %%
teams_batting = get_table_batting_2(2019, team = True)
teams_batting.head()
# Out:
#         Team     G    PA   HR    R  RBI  SB     BB%      K%   ISO BABIP   AVG  \
# 1     Astros  2309  6394  288  920  891  67  10.1 %  18.2 %  .221  .296  .274
# 2    Dodgers  2413  6281  279  886  861  57   9.7 %  21.6 %  .215  .291  .257
# 3    Yankees  2312  6245  306  943  904  55   9.1 %  23.0 %  .222  .306  .267
# 4      Twins  2320  6392  307  939  906  28   8.2 %  20.9 %  .224  .300  .270
# 5  Athletics  2363  6269  257  845  800  49   9.2 %  21.3 %  .199  .282  .249
#
#     OBP   SLG  wOBA wRC+   BsR    Off    Def   WAR
# 1  .352  .495  .355  125  -9.5  196.6   -2.5  40.8
# 2  .338  .472  .338  111  11.9  102.9   51.7  34.8
# 3  .339  .490  .346  117  -0.8  130.8  -14.5  32.7
# 4  .338  .494  .347  116  -8.4  120.2  -26.7  31.0
# 5  .327  .448  .327  107  -1.7   53.4   18.3  28.5

# %%
pd.set_option('display.max_rows', None)

# %%
players_pitching = get_table_pitching_2(2019, team = False)
players_pitching.head()
# Out:
#                Name       Team   W   L SV   G  GS     IP     SO   K/9  BB/9  \
# 1       Gerrit Cole     Astros  20   5  0  33  33  212.1  13.82  2.03  1.23
# 2      Jacob deGrom       Mets  11   8  0  32  32  204.0  11.25  1.94  0.84
# 3        Lance Lynn    Rangers  16  11  0  33  33  208.1  10.63  2.55  0.91
# 4      Max Scherzer  Nationals  11   7  0  27  27  172.1  12.69  1.72  0.94
# 5  Justin Verlander     Astros  21   6  0  34  34  223.0  12.11  1.70  1.45
#
#    HR/9   BABIP    LOB%     GB% HR/FB   ERA   FIP xFIP   WAR
# 1  .275  83.3 %  40.3 %  16.9 %  2.50  2.64  2.48  7.4  None
# 2  .282  81.8 %  44.4 %  11.2 %  2.43  2.67  3.11  7.0  None
# 3  .322  74.4 %  40.3 %   9.9 %  3.67  3.13  3.85  6.8  None
# 4  .321  78.7 %  40.8 %  11.6 %  2.92  2.45  2.88  6.5  None
# 5  .218  88.4 %  35.9 %  16.0 %  2.58  3.27  3.18  6.4  None

# %%
players_pitching
# Out:
#                   Name          Team   W   L SV   G  GS     IP     SO   K/9  \
# 1          Gerrit Cole        Astros  20   5  0  33  33  212.1  13.82  2.03
# 2         Jacob deGrom          Mets  11   8  0  32  32  204.0  11.25  1.94
# 3           Lance Lynn       Rangers  16  11  0  33  33  208.1  10.63  2.55
# 4         Max Scherzer     Nationals  11   7  0  27  27  172.1  12.69  1.72
# 5     Justin Verlander        Astros  21   6  0  34  34  223.0  12.11  1.70
# 6       Charlie Morton          Rays  16   6  0  33  33  194.2  11.10  2.64
# 7    Stephen Strasburg     Nationals  18   6  0  33  33  209.0  10.81  2.41
# 8         Shane Bieber       Indians  15   8  0  34  33  214.1  10.88  1.68
# 9         Zack Greinke         - - -  18   5  0  33  33  208.2   8.07  1.29
# 10       Lucas Giolito     White Sox  14   9  0  29  29  176.2  11.62  2.90
# 11      Walker Buehler       Dodgers  14   4  0  30  30  182.1  10.61  1.83
# 12        Hyun-Jin Ryu       Dodgers  14   5  0  29  29  182.2   8.03  1.18
# 13      Patrick Corbin     Nationals  14   7  0  33  33  202.0  10.60  3.12
# 14       Jack Flaherty     Cardinals  11   8  0  33  33  196.1  10.59  2.52
# 15        Zack Wheeler          Mets  11   8  0  31  31  195.1   8.98  2.30
# 59  1.39  .240  76.9 %  36.4 %  12.6 %  3.52  4.59  5.02  1.5  None
# 60  1.13  .274  78.1 %  56.9 %  19.8 %  3.35  4.93  4.55  1.0  None
# 61  1.87  .295  72.6 %  46.8 %  18.2 %  4.29  5.19  4.76  1.0  None

# %%
players_batting = get_table_batting_2(2019, team = False)
players_batting.head()
# Out:
#                Name       Team    G   PA  HR    R  RBI  SB     BB%      K%  \
# 1        Mike Trout     Angels  134  600  45  110  104  11  18.3 %  20.0 %
# 2      Alex Bregman     Astros  156  690  41  122  112   5  17.2 %  12.0 %
# 3  Christian Yelich    Brewers  130  580  44  100   97  30  13.8 %  20.3 %
# 4    Cody Bellinger    Dodgers  156  660  47  121  115  15  14.4 %  16.4 %
# 5     Marcus Semien  Athletics  162  747  33  123   92  10  11.6 %  13.7 %
#
#    ... BABIP   AVG   OBP   SLG  wOBA wRC+   BsR   Off   Def  WAR
# 1  ...  .298  .291  .438  .645  .436  180   7.1  68.2  -0.3  8.6
# 2  ...  .281  .296  .423  .592  .418  168  -2.1  58.2   4.8  8.5
# 3  ...  .355  .329  .429  .671  .442  174   8.5  65.2  -3.9  7.8
# 4  ...  .302  .305  .406  .629  .415  162   1.4  55.3   3.4  7.8
# 5  ...  .294  .285  .369  .522  .373  137   1.7  37.5  14.1  7.6
#
# [5 rows x 21 columns]

# %%
players_batting
# Out:
#                       Name          Team    G   PA  HR    R  RBI  SB     BB%  \
# 1               Mike Trout        Angels  134  600  45  110  104  11  18.3 %
# 2             Alex Bregman        Astros  156  690  41  122  112   5  17.2 %
# 3         Christian Yelich       Brewers  130  580  44  100   97  30  13.8 %
# 4           Cody Bellinger       Dodgers  156  660  47  121  115  15  14.4 %
# 5            Marcus Semien     Athletics  162  747  33  123   92  10  11.6 %
# 6              Ketel Marte  Diamondbacks  144  628  32   97   92  10   8.4 %
# 7           Anthony Rendon     Nationals  146  646  34  117  126   5  12.4 %
# 8          Xander Bogaerts       Red Sox  155  698  33  110  117   4  10.9 %
# 9             Mookie Betts       Red Sox  150  706  29  135   80  16  13.7 %
# 10         George Springer        Astros  122  556  39   96   96   6  12.1 %
# 11            Matt Chapman     Athletics  156  670  36  102   91   1  10.9 %
# 12           Rafael Devers       Red Sox  156  702  32  129  115   8   6.8 %
# 13           Nolan Arenado       Rockies  155  662  41  102  118   3   9.4 %
# 14            Trevor Story       Rockies  145  656  35  111   85  23   8.8 %
# 15           J.T. Realmuto      Phillies  145  593  25   92   83   9   6.9 %
# 16            Yoan Moncada     White Sox  132  559  25   83   79  10   7.2 %
# 17        Ronald Acuna Jr.        Braves  156  715  41  127  101  37  10.6 %
# 18             DJ LeMahieu       Yankees  145  655  26  109  102   5   7.0 %
# 19         Yasmani Grandal       Brewers  153  632  28   79   77   5  17.2 %
# 20          Josh Donaldson        Braves  155  659  37   96   94   4  15.2 %
# 21            Peter Alonso          Mets  161  693  53  103  120   1  10.4 %
# 22               Juan Soto     Nationals  150  659  34  110  110  12  16.4 %
# 110           Leury Garcia     White Sox  140  618   8   93   40  15   3.4 %
# 111         Starlin Castro       Marlins  162  676  22   68   86   2   4.1 %
# 112            Alex Gordon        Royals  150  633  13   77   76   5   8.1 %
# 113            Yasiel Puig         - - -  149  611  24   76   84  19   7.2 %
# 114          Eddie Rosario         Twins  137  590  32   91  109   3   3.7 %
# 115           Jason Kipnis       Indians  121  511  17   52   65   7   7.8 %
# 116         Yolmer Sanchez     White Sox  149  555   2   59   43   5   7.9 %
# 117           Josh Reddick        Astros  141  550  14   57   56   5   6.5 %
# 118          Franmil Reyes         - - -  150  548  37   69   81   0   8.6 %
# 119             Joey Votto          Reds  142  608  15   79   47   5  12.5 %
# 120           Ryan McMahon       Rockies  141  539  24   70   83   5  10.4 %
# 121           Renato Nunez       Orioles  151  599  31   72   90   1   7.3 %
# 122         Randal Grichuk     Blue Jays  151  628  31   75   80   2   5.6 %
# 123           Brandon Belt        Giants  156  616  17   76   57   4  13.5 %
# 124  Vladimir Guerrero Jr.     Blue Jays  123  514  15   52   69   0   8.9 %
# 125       Brandon Crawford        Giants  147  560  11   58   59   3   9.5 %
# 126           Rougned Odor       Rangers  145  581  30   77   93  11   9.0 %
# 127            Colin Moran       Pirates  149  503  13   46   80   0   6.0 %
# 128        Domingo Santana      Mariners  121  507  21   63   69   8   9.9 %
# 129           Mallex Smith      Mariners  134  566   6   70   37  46   7.4 %
# 130             Adam Jones  Diamondbacks  137  528  16   66   67   2   5.9 %
# 131         Miguel Cabrera        Tigers  136  549  12   41   59   0   8.7 %
# 132            Eric Hosmer        Padres  160  667  22   72   99   0   6.0 %
# 133          Albert Pujols        Angels  131  545  23   55   93   3   7.9 %
# 134          Orlando Arcia       Brewers  152  546  15   51   59   8   7.9 %
# 135            Khris Davis     Athletics  133  533  23   61   73   0   8.8 %
#
#          K%  ... BABIP   AVG   OBP   SLG  wOBA wRC+   BsR    Off    Def   WAR
# 1    20.0 %  ...  .298  .291  .438  .645  .436  180   7.1   68.2   -0.3   8.6
# 2    12.0 %  ...  .281  .296  .423  .592  .418  168  -2.1   58.2    4.8   8.5
# 3    20.3 %  ...  .355  .329  .429  .671  .442  174   8.5   65.2   -3.9   7.8
# 4    16.4 %  ...  .302  .305  .406  .629  .415  162   1.4   55.3    3.4   7.8
# 5    13.7 %  ...  .294  .285  .369  .522  .373  137   1.7   37.5   14.1   7.6
# 6    13.7 %  ...  .342  .329  .389  .592  .405  150   4.2   46.0    6.7   7.1
# 7    13.3 %  ...  .323  .319  .412  .598  .413  154   0.4   46.5    4.2   7.0
# 8    17.5 %  ...  .338  .309  .384  .555  .390  141   1.0   37.6    8.1   6.8
# 9    14.3 %  ...  .309  .295  .391  .524  .380  135   5.6   37.0    6.3   6.6
# 10   20.3 %  ...  .305  .292  .383  .591  .400  156   0.9   40.9    6.4   6.5
# 11   21.9 %  ...  .270  .249  .342  .506  .354  125   0.9   22.4   17.1   6.1
# 12   17.0 %  ...  .339  .311  .361  .555  .377  132   2.3   31.4    4.9   5.9
# 13   14.0 %  ...  .312  .315  .379  .583  .392  128   2.5   27.1   12.5   5.9
# 14   26.5 %  ...  .361  .294  .363  .554  .380  121   5.9   23.8   15.1   5.8
# 15   20.7 %  ...  .309  .275  .328  .493  .340  108   5.4   11.7   27.8   5.7
# 16   27.5 %  ...  .406  .315  .367  .548  .379  141   3.5   32.6    6.1   5.7
# 17   26.3 %  ...  .337  .280  .365  .518  .369  126   8.1   33.0    1.5   5.6
# 18   13.7 %  ...  .349  .327  .375  .518  .375  136  -0.8   29.2    2.8   5.4
# 19   22.0 %  ...  .279  .246  .380  .468  .361  121  -5.1   12.6   20.6   5.2
# 20   23.5 %  ...  .292  .259  .379  .521  .377  132  -3.0   24.9    4.5   4.9
# 21   26.4 %  ...  .280  .260  .358  .583  .384  143  -2.2   37.0   -9.7   4.8
# 22   20.0 %  ...  .312  .282  .401  .548  .394  142  -0.5   35.9   -7.5   4.8
# 23   25.3 %  ...  .283  .251  .374  .515  .372  134   4.8   31.3   -0.8   4.8
# 24   22.9 %  ...  .331  .282  .382  .521  .379  135   3.8   32.9   -4.1   4.8
# 25   16.0 %  ...  .325  .295  .352  .500  .354  117   4.8   20.1    4.6   4.6
# 26   26.1 %  ...  .313  .260  .372  .510  .365  125  -0.6   21.9    3.0   4.6
# 27   13.2 %  ...  .337  .318  .384  .531  .384  143  -2.9   29.4   -0.8   4.6
# 28   28.5 %  ...  .312  .271  .358  .572  .381  133  -6.2   22.6    1.9   4.5
# 29   16.6 %  ...  .244  .252  .336  .519  .355  121  -1.8   14.4   10.0   4.4
# 30   27.8 %  ...  .345  .281  .316  .531  .347  114   1.2   11.2   15.7   4.4
# 31   15.0 %  ...  .291  .284  .335  .518  .349  114  -2.0    9.9   12.1   4.4
# 32   15.7 %  ...  .293  .281  .397  .515  .380  135   1.5   31.9  -11.1   4.4
# 33   25.1 %  ...  .351  .311  .392  .639  .417  163  -4.5   37.7  -12.3   4.3
# 34   10.4 %  ...  .320  .311  .372  .503  .367  133   0.0   27.2   -6.8   4.2
# 35   22.4 %  ...  .259  .233  .318  .444  .322  100   2.3    2.2   18.5   4.1
# 36   16.5 %  ...  .328  .295  .356  .485  .352  119   3.1   20.6   -3.9   4.0
# 37   22.2 %  ...  .331  .291  .364  .558  .380  142  -1.0   31.0  -10.3   4.0
# 38   14.0 %  ...  .306  .293  .405  .520  .390  141  -5.4   28.2   -6.9   4.0
# 39   18.4 %  ...  .318  .295  .389  .549  .387  138  -0.1   34.9  -16.2   4.0
# 40   24.6 %  ...  .341  .274  .339  .453  .335  107  10.5   17.0   -1.4   4.0
# 41   25.2 %  ...  .300  .267  .351  .545  .368  134  -0.5   23.5   -3.0   3.9
# 42   23.0 %  ...  .290  .257  .363  .494  .358  126   1.4   23.6   -6.0   3.7
# 43   15.1 %  ...  .321  .285  .361  .423  .334  108   7.1   12.9    7.2   3.7
# 44   18.6 %  ...  .283  .269  .320  .511  .341  109   2.9   11.1    3.9   3.7
# 45   21.4 %  ...  .296  .278  .337  .535  .358  125  -0.5   18.7   -2.6   3.6
# 78   11.7 %  ...  .333  .308  .353  .446  .339  110  -0.2    6.7    0.5   2.4
# 79   16.2 %  ...  .319  .279  .365  .428  .342  107   3.5   10.0   -7.0   2.3
# 80   11.8 %  ...  .302  .280  .323  .420  .315   92   5.7   -0.9    5.0   2.3
# 81   25.7 %  ...  .312  .259  .348  .476  .346  112   2.6   12.0   -8.4   2.2
# 82   12.3 %  ...  .306  .278  .336  .417  .320   97   0.7   -1.6    4.9   2.2
# 83   24.5 %  ...  .267  .226  .364  .454  .347  113  -2.7    9.2   -9.8   2.2
# 84   22.8 %  ...  .333  .266  .343  .431  .330  100   2.7    3.1   -4.1   2.0
# 85   22.0 %  ...  .291  .254  .325  .437  .322  101  -1.3   -0.6    4.6   2.0
# 86   16.4 %  ...  .334  .314  .364  .576  .387  125  -4.5   16.7  -16.9   2.0
# 87   20.7 %  ...  .325  .285  .343  .505  .354  117  -0.7   10.5   -6.9   1.9
# 88   18.7 %  ...  .281  .251  .343  .429  .328  101   2.1    2.6   -1.7   1.9
# 89   29.5 %  ...  .353  .283  .324  .534  .352  111   4.6   11.6   -9.8   1.9
# 90   11.8 %  ...  .314  .284  .331  .379  .305   90  -2.9   -9.8   12.6   1.9
# 91    9.1 %  ...  .318  .305  .329  .422  .318   96  -1.7   -4.7    4.8   1.9
# 92   20.0 %  ...  .294  .260  .342  .441  .331   98  -4.2   -5.4    6.9   1.9
# 93   21.9 %  ...  .320  .284  .330  .503  .344  117  -5.3    9.7  -15.0   1.9
# 94   26.6 %  ...  .308  .267  .315  .513  .343  116   1.8   12.3  -11.0   1.9
# 95   23.6 %  ...  .340  .282  .332  .464  .334  112  -3.5    4.3   -4.2   1.8
# 96   25.0 %  ...  .333  .265  .371  .455  .353  112   3.8   13.8  -19.2   1.7
# 97   15.0 %  ...  .313  .279  .333  .408  .315   92   1.5   -5.5    1.6   1.7
# 98   27.8 %  ...  .345  .263  .378  .464  .360  126  -3.8   12.9  -13.6   1.7
# 99   26.7 %  ...  .232  .208  .341  .439  .333  111  -0.1    7.7  -11.2   1.6
# 100  13.2 %  ...  .315  .288  .318  .407  .306   84  -1.9  -13.0   11.9   1.6
# 101  24.7 %  ...  .294  .238  .346  .409  .326  103  -0.3    1.6   -4.7   1.5
# 102  17.0 %  ...  .301  .260  .325  .372  .302   83   0.4  -13.8    9.0   1.5
# 103  22.8 %  ...  .300  .251  .325  .422  .317   92   3.9   -1.5   -0.8   1.5
# 104  13.8 %  ...  .270  .259  .287  .432  .298   85   6.0   -6.8    1.2   1.5
# 105  14.8 %  ...  .305  .275  .313  .393  .300   76   3.5  -16.6    8.5   1.4
# 106  13.2 %  ...  .310  .288  .351  .416  .327  105  -5.8   -2.1   -0.1   1.4
# 107  24.6 %  ...  .312  .260  .296  .438  .307   89  -0.8   -9.0    3.1   1.4
# 108  27.3 %  ...  .281  .225  .317  .421  .314   90   0.5   -7.0    1.3   1.4
# 109  14.5 %  ...  .218  .218  .301  .410  .301   89   1.8   -5.3    0.7   1.3
# 110  22.5 %  ...  .353  .279  .310  .378  .294   83   5.6   -7.6   -0.9   1.3
# 111  16.4 %  ...  .293  .270  .300  .436  .307   91  -4.2  -12.1    3.6   1.3
# 112  15.8 %  ...  .301  .266  .345  .396  .319   96  -2.4   -5.9   -3.5   1.3
# 113  21.8 %  ...  .308  .267  .327  .458  .330  101  -0.9   -0.5   -7.1   1.2
# 114  14.6 %  ...  .273  .276  .300  .500  .329  103   0.2    2.8  -11.7   1.2
# 115  17.2 %  ...  .265  .245  .304  .410  .301   82   0.0  -11.9    4.8   1.1
# 116  21.1 %  ...  .324  .252  .318  .321  .281   74   2.0  -16.3    7.0   1.0
# 117  12.0 %  ...  .288  .275  .319  .409  .308   94   0.4   -4.1   -4.9   1.0
# 118  28.5 %  ...  .279  .249  .310  .512  .338  109  -3.2    3.1  -11.5   1.0
# 119  20.2 %  ...  .313  .261  .357  .411  .332  101  -3.9   -3.3   -9.4   0.7
# 120  29.7 %  ...  .323  .250  .329  .450  .330   88   0.1   -8.7   -2.6   0.6
# 121  23.9 %  ...  .272  .244  .311  .460  .323   99   0.3   -0.7  -14.7   0.6
# 122  26.0 %  ...  .266  .232  .280  .457  .307   90  -3.8  -12.1   -4.5   0.5
# 123  20.6 %  ...  .275  .234  .339  .403  .319   99  -1.6   -2.5  -12.9   0.5
# 124  17.7 %  ...  .308  .272  .339  .433  .329  105  -6.6   -3.4  -10.6   0.4
# 125  20.9 %  ...  .274  .228  .304  .350  .281   74  -0.9  -20.2    5.9   0.4
# 126  30.6 %  ...  .244  .205  .283  .439  .302   77   2.2  -14.9   -2.3   0.3
# 127  23.3 %  ...  .341  .277  .322  .429  .315   94  -3.4   -7.4   -7.8   0.1
# 128  32.3 %  ...  .347  .253  .329  .441  .326  107   0.5    4.8  -22.4   0.0
# 129  24.9 %  ...  .302  .227  .300  .335  .278   74   8.5  -10.4   -9.3   0.0
# 130  19.1 %  ...  .296  .260  .313  .414  .308   87  -2.0  -10.9   -7.5  -0.1
# 131  19.7 %  ...  .336  .282  .346  .398  .318   96  -6.3   -8.9  -13.9  -0.3
# 132  24.4 %  ...  .323  .265  .310  .425  .309   91  -5.2  -13.1  -12.4  -0.4
# 133  12.5 %  ...  .238  .244  .305  .430  .308   93  -4.4   -9.3  -13.9  -0.4
# 134  20.0 %  ...  .253  .223  .283  .350  .269   61   0.9  -27.3    5.4  -0.4
# 135  27.4 %  ...  .264  .220  .293  .387  .289   81  -2.2  -15.2  -13.5  -1.0
#
# [135 rows x 21 columns]

# %%
num_teams = len(teams_batting)
num_teams
# Out:
# 30

# %%
num_batters = len(players_batting)
num_batters
# Out:
# 135

# %%
num_pitchers = len(players_pitching)
num_pitchers
# Out:
# 61

# %% [markdown]
# Ok, I think we have at least some of the **data**!
#
# However, if you look at the Web site, you will see we ***still did not get all the data***? Can you fix this?
#
# On to the **model**!

# %% [markdown]
# # Offense parameters
#
# From [Sabermetrics](https://en.wikipedia.org/wiki/Sabermetrics), I get the important player attack parameters:
#
# - [On-Base plus Slugging](https://en.wikipedia.org/wiki/On-base_plus_slugging): Ability of a player both to get on base and to hit for power (OPS = OBP + SLG)
# - [Wins Above Replacement](https://en.wikipedia.org/wiki/Wins_Above_Replacement): Sums up a player's total contributions to his team

# %%
# adding a new calculated field
players_batting['OPS'] = players_batting['OBP'] + players_batting['SLG']

# %% [markdown]
# This will be my reduced dataset:

# %%
attack = players_batting[['Name', 'Team', 'OPS', 'WAR']]
attack.head()
# Out:
#                Name       Team       OPS  WAR
# 1        Mike Trout     Angels  .438.645  8.6
# 2      Alex Bregman     Astros  .423.592  8.5
# 3  Christian Yelich    Brewers  .429.671  7.8
# 4    Cody Bellinger    Dodgers  .406.629  7.8
# 5     Marcus Semien  Athletics  .369.522  7.6

# %% [markdown]
# # Defense parameters
#
# After reading [this](https://www.beyondtheboxscore.com/2014/6/2/5758898/sabermetrics-stats-pitching-stats-learn-sabermetrics) article, I will pick BABIP and FIP as representative of pitching prowess, and focus solely on pitching as defense. Obviously, fielding and throwing and closing are three other big dimensions of the game, which i neglect here.

# %%
defense = players_pitching[['Name', 'Team', 'BABIP', 'FIP']]
defense.head()
# Out:
#                Name       Team   BABIP   FIP
# 1       Gerrit Cole     Astros  83.3 %  2.48
# 2      Jacob deGrom       Mets  81.8 %  3.11
# 3        Lance Lynn    Rangers  74.4 %  3.85
# 4      Max Scherzer  Nationals  78.7 %  2.88
# 5  Justin Verlander     Astros  88.4 %  3.18

# %% [markdown]
# # Game summary statistics
#
# The right way of proceeding is to analyze ***every game of the season*** (like the football notbook does). But it's ok to start with a simpler model as ***first iteration***. So instead of looking at every game, i'm going to look at ***season averages***.  Note that in the football notebook, we modelled each **game played**, whereas here, we are modelling a **season**. Always start with ***a very simple model***.
#
# For team power, I will concentrate on the differential between game wins and losses in the season in the same way as goal differential per game in  my football notebook.
#
# I will also neglect home field advantage.

# %%
teams_pitching['WLdiff'] = teams_pitching['W'].astype(int) - teams_pitching['L'].astype(int)
teams = teams_pitching[['Team', 'WLdiff']]
teams.sort_values(by=['WLdiff'], ascending=False).head(20)
# Out:
#             Team  WLdiff
# 4         Astros      52
# 2        Dodgers      50
# 10       Yankees      44
# 3          Twins      40
# 8      Athletics      32
# 18        Braves      32
# 1           Rays      30
# 5      Nationals      24
# 6        Indians      24
# 13     Cardinals      20
# 17       Brewers      16
# 7           Mets      10
# 16  Diamondbacks       8
# 12       Red Sox       6
# 11          Cubs       6
# 23      Phillies       0
# 15       Rangers      -6
# 25        Giants      -8
# 9           Reds     -12
# 19     White Sox     -17

# %%
len(teams)

# %%
teams_batting['RBIs'] = teams_batting['RBI'].astype(int)
teams2 = teams_batting[['Team', 'RBIs']]
teams2.sort_values(by=['RBIs'], ascending=False).head(20)
# Out:
#             Team  RBIs
# 4          Twins   906
# 3        Yankees   904
# 1         Astros   891
# 2        Dodgers   861
# 6        Red Sox   857
# 7         Braves   824
# 8      Nationals   824
# 24       Rockies   803
# 5      Athletics   800
# 9           Cubs   783
# 12  Diamondbacks   778
# 11          Mets   767
# 27       Rangers   765
# 10       Brewers   744
# 15      Phillies   742
# 16        Angels   734
# 17       Indians   731
# 18      Mariners   730
# 13          Rays   730
# 23       Pirates   722

# %%
teams['Team'].values
# Out:
# array(['Rays', 'Dodgers', 'Twins', 'Astros', 'Nationals', 'Indians',
#        'Mets', 'Athletics', 'Reds', 'Yankees', 'Cubs', 'Red Sox',
#        'Cardinals', 'Padres', 'Rangers', 'Diamondbacks', 'Brewers',
#        'Braves', 'White Sox', 'Tigers', 'Blue Jays', 'Pirates',
#        'Phillies', 'Royals', 'Giants', 'Rockies', 'Marlins', 'Mariners',
#        'Angels', 'Orioles'], dtype=object)

# %%
teams2['Team'].values
# Out:
# array(['Astros', 'Dodgers', 'Yankees', 'Twins', 'Athletics', 'Red Sox',
#        'Braves', 'Nationals', 'Cubs', 'Brewers', 'Mets', 'Diamondbacks',
#        'Rays', 'Cardinals', 'Phillies', 'Angels', 'Indians', 'Mariners',
#        'Padres', 'Blue Jays', 'Reds', 'White Sox', 'Pirates', 'Rockies',
#        'Giants', 'Royals', 'Rangers', 'Orioles', 'Marlins', 'Tigers'],
#       dtype=object)

# %%
teams_ = teams.set_index('Team')
teams_
# Out:
#               WLdiff
# Team
# Rays              30
# Dodgers           50
# Twins             40
# Astros            52
# Nationals         24
# Indians           24
# Mets              10
# Athletics         32
# Reds             -12
# Yankees           44
# Cubs               6
# Red Sox            6
# Cardinals         20
# Padres           -22
# Rangers           -6
# Diamondbacks       8
# Brewers           16
# Braves            32
# White Sox        -17
# Tigers           -67
# Blue Jays        -28
# Pirates          -24
# Phillies           0
# Royals           -44
# Giants            -8
# Rockies          -20
# Marlins          -48
# Mariners         -26
# Angels           -18
# Orioles          -54

# %%
observed_wins_losses = teams_['WLdiff'].values
observed_wins_losses
# Out:
# array([ 30,  50,  40,  52,  24,  24,  10,  32, -12,  44,   6,   6,  20,
#        -22,  -6,   8,  16,  32, -17, -67, -28, -24,   0, -44,  -8, -20,
#        -48, -26, -18, -54])

# %%
mlb_teams_by_wins_losses = teams_.index
mlb_teams_by_wins_losses
# Out:
# Index(['Rays', 'Dodgers', 'Twins', 'Astros', 'Nationals', 'Indians', 'Mets',
#        'Athletics', 'Reds', 'Yankees', 'Cubs', 'Red Sox', 'Cardinals',
#        'Padres', 'Rangers', 'Diamondbacks', 'Brewers', 'Braves', 'White Sox',
#        'Tigers', 'Blue Jays', 'Pirates', 'Phillies', 'Royals', 'Giants',
#        'Rockies', 'Marlins', 'Mariners', 'Angels', 'Orioles'],
#       dtype='object', name='Team')

# %%
teams2_ = teams2.set_index('Team')
teams2_
# Out:
#               RBIs
# Team
# Astros         891
# Dodgers        861
# Yankees        904
# Twins          906
# Athletics      800
# Red Sox        857
# Braves         824
# Nationals      824
# Cubs           783
# Brewers        744
# Mets           767
# Diamondbacks   778
# Rays           730
# Cardinals      714
# Phillies       742
# Angels         734
# Indians        731
# Mariners       730
# Padres         652
# Blue Jays      697
# Reds           679
# White Sox      676
# Pirates        722
# Rockies        803
# Giants         655
# Royals         655
# Rangers        765
# Orioles        698
# Marlins        593
# Tigers         556

# %%
teams3_ = teams2_.sort_values(by=['RBIs'], ascending=False)
teams3_.head(20)
# Out:
#               RBIs
# Team
# Twins          906
# Yankees        904
# Astros         891
# Dodgers        861
# Red Sox        857
# Braves         824
# Nationals      824
# Rockies        803
# Athletics      800
# Cubs           783
# Diamondbacks   778
# Mets           767
# Rangers        765
# Brewers        744
# Phillies       742
# Angels         734
# Indians        731
# Mariners       730
# Rays           730
# Pirates        722

# %%
observed_rbis = teams3_['RBIs'].values
observed_rbis
# Out:
# array([906, 904, 891, 861, 857, 824, 824, 803, 800, 783, 778, 767, 765,
#        744, 742, 734, 731, 730, 730, 722, 714, 698, 697, 679, 676, 655,
#        655, 652, 593, 556])

# %%
mlb_teams_by_rbis = teams3_.index
mlb_teams_by_rbis
# Out:
# Index(['Twins', 'Yankees', 'Astros', 'Dodgers', 'Red Sox', 'Braves',
#        'Nationals', 'Rockies', 'Athletics', 'Cubs', 'Diamondbacks', 'Mets',
#        'Rangers', 'Brewers', 'Phillies', 'Angels', 'Indians', 'Mariners',
#        'Rays', 'Pirates', 'Cardinals', 'Orioles', 'Blue Jays', 'Reds',
#        'White Sox', 'Giants', 'Royals', 'Padres', 'Marlins', 'Tigers'],
#       dtype='object', name='Team')

# %%
mlb_teams_by_rbis_df = pd.DataFrame(mlb_teams_by_rbis)
mlb_teams_by_rbis_df
# Out:
#             Team
# 0          Twins
# 1        Yankees
# 2         Astros
# 3        Dodgers
# 4        Red Sox
# 5         Braves
# 6      Nationals
# 7        Rockies
# 8      Athletics
# 9           Cubs
# 10  Diamondbacks
# 11          Mets
# 12       Rangers
# 13       Brewers
# 14      Phillies
# 15        Angels
# 16       Indians
# 17      Mariners
# 18          Rays
# 19       Pirates
# 20     Cardinals
# 21       Orioles
# 22     Blue Jays
# 23          Reds
# 24     White Sox
# 25        Giants
# 26        Royals
# 27        Padres
# 28       Marlins
# 29        Tigers

# %%
mlb_teams_by_rbis_index = mlb_teams_by_rbis_df.index
mlb_teams_by_rbis_index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
(teams_
      .plot(kind='bar', title='Major League Baseball 2019 Season Wins & Losses')
      .set_ylabel('Wins minus Losses'));

# %%
(teams3_
      .plot(kind='bar', title='Major League Baseball 2019 Season RBIs')
      .set_ylabel('RBIs'));

# %% [markdown]
# Do you see how Twins, Yankees, Astros, and Dodgers scored many RBIs and also figure on top in the Wins - Losses board? But who's ***right after them***, with *almost the same amount of RBIs*, and yet is *not* playing in this posteason?
#
# </br >
# <center>
# <img src="ipynb.images/redsox.jpg" width=200 />
# </center>
#
# So although the Red Sox was a power hitting team, their **defense** and/or their **coaching**/game-strategy was ***sub-par***. In the end, it's **Wins** minus **Losses** that takes you to the post-season, not RBIs.

# %% [markdown]
# ## Building a Bayesian Model: The Priors
#
# We know that a count outcome is most often modelled as a Poisson distribution. We will model **effective** team strength as $y$ as a Poisson distribution: $(y\;|\;θ_j) \propto Poisson(θ_j)$ where the $\theta_j$ parameters represent team attacking (OPS and WAR) and defensive parameters (BABIP and FIP).
#
# Instead of considering the OPS and WAR of each batter, and the BABIP and FIP of each hitter, we'll simplify and consider only the top 5 batters in the [batting order](https://en.wikipedia.org/wiki/Batting_order_(baseball), and the top 5 starting pitchers in the [pitching rotation](https://en.wikipedia.org/wiki/Starting_pitcher).
#
# We aren't even considering the **bullpen pitchers** (closers), who make ***such a huge difference in the last 3 innings***!
#
# So how many prior parameters in total? **5 \* 2 + 5 \* 2 = 20 per team**. For 30 teams, this is a total of ***600 model parameters***!
#
# We will model our ***per-team*** $\theta$ as an exponential of **twenty** independent variables: two attack variables **att** for each of the top 5 batters, and two defense variables **def** for each of the top 5 pitchers, times a constant factor k. We won't base this on a ***per game***/played (e.g. $att_g$) model as we did with football (although we could have, but then maybe we have so many more model parameters that we probably need to run on AWS), but on a ***per team***/season model (e.g. $att_t$).
#
# Let's assume the index $b$ for batters (attack), and $p$ for pitchers (defense).
#
# $$θ = k * \Pi_be^{\text{att1}_b} * \Pi_be^{\text{att2}_b} * \Pi_pe^{\text{def1}_p} * \Pi_pe^{\text{def2}_p}$$
#
# Our priors are thus modeled with a **log-linear** random effect model, a common procedure in sports analytics.
#
# $$\log(θ) = \text{intercept} + \sum_b\text{att1}_b + \sum_b\text{att2}_b + \sum_p\text{def1}_p + \sum_p\text{def2}_p$$
#
# For each team $t = 1, \cdots, T$, team-specific attack and defense effects are modelled from normal distributions:
# $att1_b \propto \text{Normal}(μ_{att1},τ_{att1})$, $att2_b \propto \text{Normal}(μ_{att2},τ_{att2})$, and $def1_p \propto \text{Normal}(μ_{def1}, τ_{def1})$, $def2_p \propto \text{Normal}(μ_{def2}, τ_{def2})$.
#
# To further simplify, we'll set $τ_{att2} = τ_{att1}$ and $τ_{def2} = τ_{def1}$.
#
# We now build a model in `PyMC3`, specifying global parameters, team-specific parameters, and likelihood function.

# %% [markdown]
# # On 2nd thought..
#
# This model *may* work, but it's the ***wrong start***. Too complex for a start. We need to take baby steps!
#
# </br >
# <center>
# <img src="ipynb.images/baby-steps.png" width=400 />
# </center>
#
# So wjat we'll do is to ***sum*** the attack & defense factors we picked from the top-5 pitchers and batters. Since `fangraphs` is throttling our requests, we'll just get as many players from each team as we can.
#
# Batters:
# - WAR
# - OBS = OBP + SLG
#
# Pitchers:
# - BABIF
# - FIP

# %% [markdown]
# ## Batters

# %%
players_batting_war = players_batting[['Name', 'Team', 'WAR']]
players_batting_war.head()
# Out:
#                Name       Team  WAR
# 1        Mike Trout     Angels  8.6
# 2      Alex Bregman     Astros  8.5
# 3  Christian Yelich    Brewers  7.8
# 4    Cody Bellinger    Dodgers  7.8
# 5     Marcus Semien  Athletics  7.6

# %%
players_batting_war.groupby(['Team'])['WAR'].agg('sum')
# Out:
# Team
# - - -              2.81.91.51.41.21.0
# Angels                  8.63.42.5-0.4
# Astros             8.56.54.23.53.21.0
# Athletics            7.66.13.91.3-1.0
# Blue Jays                      0.50.4
# Braves                5.64.94.64.01.5
# Brewers           7.85.22.81.91.5-0.4
# Cardinals             4.13.72.92.61.5
# Cubs                  4.84.44.02.61.9
# Diamondbacks         7.13.72.42.2-0.1
# Dodgers               7.84.83.43.33.0
# Giants                      2.00.50.4
# Indians                  4.44.43.31.1
# Mariners                    1.60.00.0
# Marlins                     3.11.91.3
# Mets                  4.84.63.72.71.4
# Nationals             7.04.83.52.52.3
# Orioles                  4.03.61.90.6
# Padres                        3.1-0.4
# Phillies              5.74.62.32.21.7
# Pirates            3.23.02.52.42.20.1
# Rangers                  1.91.71.40.3
# Rays                     4.03.32.81.8
# Red Sox         6.86.65.93.53.22.01.4
# Reds                        4.51.60.7
# Rockies                  5.95.82.00.6
# Royals                   3.63.02.91.3
# Tigers                           -0.3
# Twins                    4.44.34.01.2
# White Sox          5.73.51.91.91.31.0
# Yankees                  5.43.63.61.7
# Name: WAR, dtype: object

# %% [markdown]
# Hmm.. Why are we getting averages as string concatenations? Can you guess?

# %% [markdown]
# <div style="display:none;">
# Because WARs are listed as string types! So let's convert them to floats!
# </div>

# %%
players_batting['WARs'] = players_batting['WAR'].astype(float) 
players_batting_war = players_batting[['Name', 'Team', 'WARs']]
players_batting_war.head()
# Out:
#                Name       Team  WARs
# 1        Mike Trout     Angels   8.6
# 2      Alex Bregman     Astros   8.5
# 3  Christian Yelich    Brewers   7.8
# 4    Cody Bellinger    Dodgers   7.8
# 5     Marcus Semien  Athletics   7.6

# %%
wars = players_batting_war.groupby(['Team'])['WARs'].agg('sum')
wars
# Out:
# Team
# - - -            9.8
# Angels          14.1
# Astros          26.9
# Athletics       17.9
# Blue Jays        0.9
# Braves          20.6
# Brewers         18.8
# Cardinals       14.8
# Cubs            17.7
# Diamondbacks    15.3
# Dodgers         22.3
# Giants           2.9
# Indians         13.2
# Mariners         1.6
# Marlins          6.3
# Mets            17.2
# Nationals       20.1
# Orioles         10.1
# Padres           2.7
# Phillies        16.5
# Pirates         13.4
# Rangers          5.3
# Rays            11.9
# Red Sox         29.4
# Reds             6.8
# Rockies         14.3
# Royals          10.8
# Tigers          -0.3
# Twins           13.9
# White Sox       15.3
# Yankees         14.3
# Name: WARs, dtype: float64

# %% [markdown]
# Let's get rid of the empty team row (first row above):

# %%
wars = wars[1:]
wars
# Out:
# Team
# Angels          14.1
# Astros          26.9
# Athletics       17.9
# Blue Jays        0.9
# Braves          20.6
# Brewers         18.8
# Cardinals       14.8
# Cubs            17.7
# Diamondbacks    15.3
# Dodgers         22.3
# Giants           2.9
# Indians         13.2
# Mariners         1.6
# Marlins          6.3
# Mets            17.2
# Nationals       20.1
# Orioles         10.1
# Padres           2.7
# Phillies        16.5
# Pirates         13.4
# Rangers          5.3
# Rays            11.9
# Red Sox         29.4
# Reds             6.8
# Rockies         14.3
# Royals          10.8
# Tigers          -0.3
# Twins           13.9
# White Sox       15.3
# Yankees         14.3
# Name: WARs, dtype: float64

# %% [markdown]
# And let's rescale since the WAr numbers are so much higher than the other factors.

# %%
from sklearn import preprocessing
nwars = preprocessing.scale(wars) + 2
nwars
# Out:
# array([2.12766291, 3.87846848, 2.64743331, 0.32214466, 3.01674386,
#        2.77053683, 2.22341009, 2.62007697, 2.29180093, 3.24927273,
#        0.59570803, 2.00455939, 0.41789184, 1.06076576, 2.55168613,
#        2.94835302, 1.58053616, 0.56835169, 2.45593895, 2.03191573,
#        0.92398407, 1.8267432 , 4.22042269, 1.1291566 , 2.15501924,
#        1.67628334, 0.15800664, 2.10030657, 2.29180093, 2.15501924])

# %%
list(nwars)
# Out:
# [2.1276629064071564,
#  3.878468479991017,
#  2.647433311064865,
#  0.3221446586488006,
#  3.016743861742711,
#  2.7705368279574802,
#  2.2234100862125237,
#  2.6200769739776173,
#  2.291800928930644,
#  3.2492727269843176,
#  0.5957080295212787,
#  2.0045593895145415,
#  0.41789183845416766,
#  1.0607657600044915,
#  2.551686131259497,
#  2.9483530190245912,
#  1.5805361646622003,
#  0.568351692434031,
#  2.4559389514541303,
#  2.031915726601789,
#  0.9239840745682524,
#  1.8267431984474305,
#  4.2204226935816145,
#  1.129156602722611,
#  2.1550192434944044,
#  1.6762833444675675,
#  0.1580066361253134,
#  2.1003065693199083,
#  2.291800928930644,
#  2.1550192434944044]

# %%
wars = players_batting_war.groupby(['Team'])['WARs'].agg('sum')
wars

# %% [markdown]
# Now for OPS:

# %%
players_batting['OPS'] = players_batting['OBP'].astype(float) + players_batting['SLG'].astype(float)
players_batting_ops = players_batting[['Name', 'Team', 'OPS']]
players_batting_ops.head()
# Out:
#                Name       Team    OPS
# 1        Mike Trout     Angels  1.083
# 2      Alex Bregman     Astros  1.015
# 3  Christian Yelich    Brewers  1.100
# 4    Cody Bellinger    Dodgers  1.035
# 5     Marcus Semien  Athletics  0.891

# %%
opss = players_batting_ops.groupby(['Team'])['OPS'].agg('sum')
opss
# Out:
# Team
# - - -           4.705
# Angels          3.344
# Astros          5.379
# Athletics       4.026
# Blue Jays       1.509
# Braves          4.320
# Brewers         4.971
# Cardinals       3.927
# Cubs            4.317
# Diamondbacks    4.116
# Dodgers         4.500
# Giants          2.158
# Indians         3.285
# Mariners        2.185
# Marlins         2.256
# Mets            4.235
# Nationals       4.347
# Orioles         3.213
# Padres          1.531
# Phillies        4.005
# Pirates         4.964
# Rangers         3.112
# Rays            3.272
# Red Sox         6.019
# Reds            2.423
# Rockies         3.598
# Royals          3.345
# Tigers          0.744
# Twins           3.527
# White Sox       4.768
# Yankees         3.435
# Name: OPS, dtype: float64

# %%
opss = opss[1:]
opss
# Out:
# Team
# Angels          3.344
# Astros          5.379
# Athletics       4.026
# Blue Jays       1.509
# Braves          4.320
# Brewers         4.971
# Cardinals       3.927
# Cubs            4.317
# Diamondbacks    4.116
# Dodgers         4.500
# Giants          2.158
# Indians         3.285
# Mariners        2.185
# Marlins         2.256
# Mets            4.235
# Nationals       4.347
# Orioles         3.213
# Padres          1.531
# Phillies        4.005
# Pirates         4.964
# Rangers         3.112
# Rays            3.272
# Red Sox         6.019
# Reds            2.423
# Rockies         3.598
# Royals          3.345
# Tigers          0.744
# Twins           3.527
# White Sox       4.768
# Yankees         3.435
# Name: OPS, dtype: float64

# %% [markdown]
# ## Pitchers

# %%
players_pitching_babip = players_pitching[['Name', 'Team', 'BABIP']]
players_pitching_babip.head()
# Out:
#                Name       Team   BABIP
# 1       Gerrit Cole     Astros  83.3 %
# 2      Jacob deGrom       Mets  81.8 %
# 3        Lance Lynn    Rangers  74.4 %
# 4      Max Scherzer  Nationals  78.7 %
# 5  Justin Verlander     Astros  88.4 %

# %% [markdown]
# We need to get rid of the trailing ` %`:

# %%
def rchop(thestring, ending):
    if thestring.endswith(ending):
        return thestring[:-len(ending)]
    return thestring

#somestring = rchop(somestring, '  %')

# %%
players_pitching['BABIP%'] = [float(rchop(b, ' %'))/100. for b in players_pitching['BABIP']]
players_pitching['BABIP%']
# Out:
# 1     0.833
# 2     0.818
# 3     0.744
# 4     0.787
# 5     0.884
# 6     0.753
# 7     0.765
# 8     0.774
# 9     0.757
# 10    0.777
# 11    0.710
# 12    0.822
# 13    0.773
# 14    0.833
# 15    0.714
# 16    0.735
# 17    0.689
# 18    0.797
# 19    0.803
# 20    0.718
# 21    0.767
# 22    0.799
# 23    0.761
# 24    0.777
# 25    0.692
# 26    0.659
# 27    0.768
# 28    0.681
# 29    0.840
# 30    0.632
# 31    0.744
# 32    0.704
# 33    0.704
# 34    0.718
# 35    0.743
# 36    0.712
# 37    0.714
# 38    0.777
# 39    0.738
# 40    0.749
# 41    0.777
# 42    0.751
# 43    0.738
# 44    0.692
# 45    0.722
# 46    0.765
# 47    0.730
# 48    0.731
# 49    0.728
# 50    0.748
# 51    0.743
# 52    0.781
# 53    0.676
# 54    0.657
# 55    0.785
# 56    0.766
# 57    0.703
# 58    0.739
# 59    0.769
# 60    0.781
# 61    0.726
# Name: BABIP%, dtype: float64

# %%
players_pitching_babip = players_pitching[['Name', 'Team', 'BABIP%']]
players_pitching_babip.head()
# Out:
#                Name       Team  BABIP%
# 1       Gerrit Cole     Astros   0.833
# 2      Jacob deGrom       Mets   0.818
# 3        Lance Lynn    Rangers   0.744
# 4      Max Scherzer  Nationals   0.787
# 5  Justin Verlander     Astros   0.884

# %%
babips = players_pitching_babip.groupby(['Team'])['BABIP%'].agg('mean')
babips
# Out:
# Team
# - - -           0.740167
# Astros          0.820000
# Athletics       0.766500
# Braves          0.769333
# Cardinals       0.779250
# Cubs            0.717000
# Diamondbacks    0.741000
# Dodgers         0.790667
# Giants          0.743500
# Indians         0.774000
# Mariners        0.692000
# Marlins         0.738000
# Mets            0.740333
# Nationals       0.768500
# Padres          0.730000
# Phillies        0.753500
# Pirates         0.632000
# Rangers         0.773500
# Rays            0.753000
# Red Sox         0.717000
# Reds            0.780333
# Rockies         0.681000
# Royals          0.712500
# Tigers          0.744000
# Twins           0.705500
# White Sox       0.732333
# Yankees         0.704000
# Name: BABIP%, dtype: float64

# %%
babips = babips[1:]
babips
# Out:
# Team
# Astros          0.820000
# Athletics       0.766500
# Braves          0.769333
# Cardinals       0.779250
# Cubs            0.717000
# Diamondbacks    0.741000
# Dodgers         0.790667
# Giants          0.743500
# Indians         0.774000
# Mariners        0.692000
# Marlins         0.738000
# Mets            0.740333
# Nationals       0.768500
# Padres          0.730000
# Phillies        0.753500
# Pirates         0.632000
# Rangers         0.773500
# Rays            0.753000
# Red Sox         0.717000
# Reds            0.780333
# Rockies         0.681000
# Royals          0.712500
# Tigers          0.744000
# Twins           0.705500
# White Sox       0.732333
# Yankees         0.704000
# Name: BABIP%, dtype: float64

# %%
len(babips)
# Out:
# 26

# %%
players_pitching['FIPs'] = players_pitching['FIP'].astype(float)
players_pitching_fip = players_pitching[['Name', 'Team', 'FIPs']]
players_pitching_fip.head()
# Out:
#                Name       Team  FIPs
# 1       Gerrit Cole     Astros  2.48
# 2      Jacob deGrom       Mets  3.11
# 3        Lance Lynn    Rangers  3.85
# 4      Max Scherzer  Nationals  2.88
# 5  Justin Verlander     Astros  3.18

# %%
fips = players_pitching_fip.groupby(['Team'])['FIPs'].agg('mean')
fips
# Out:
# Team
# - - -           4.315000
# Astros          3.393333
# Athletics       4.990000
# Braves          4.143333
# Cardinals       4.190000
# Cubs            4.050000
# Diamondbacks    4.170000
# Dodgers         3.396667
# Giants          4.665000
# Indians         3.230000
# Mariners        5.110000
# Marlins         5.170000
# Mets            3.666667
# Nationals       3.685000
# Padres          4.360000
# Phillies        4.290000
# Pirates         4.310000
# Rangers         4.225000
# Rays            3.280000
# Red Sox         4.620000
# Reds            3.810000
# Rockies         3.540000
# Royals          4.785000
# Tigers          3.880000
# Twins           4.505000
# White Sox       4.613333
# Yankees         4.290000
# Name: FIPs, dtype: float64

# %%
fips = fips[1:]
fips
# Out:
# Team
# Astros          3.393333
# Athletics       4.990000
# Braves          4.143333
# Cardinals       4.190000
# Cubs            4.050000
# Diamondbacks    4.170000
# Dodgers         3.396667
# Giants          4.665000
# Indians         3.230000
# Mariners        5.110000
# Marlins         5.170000
# Mets            3.666667
# Nationals       3.685000
# Padres          4.360000
# Phillies        4.290000
# Pirates         4.310000
# Rangers         4.225000
# Rays            3.280000
# Red Sox         4.620000
# Reds            3.810000
# Rockies         3.540000
# Royals          4.785000
# Tigers          3.880000
# Twins           4.505000
# White Sox       4.613333
# Yankees         4.290000
# Name: FIPs, dtype: float64

# %%
len(fips)
# Out:
# 26

# %%
mlb_teams = fips.index
mlb_teams
# Out:
# Index(['Astros', 'Athletics', 'Braves', 'Cardinals', 'Cubs', 'Diamondbacks',
#        'Dodgers', 'Giants', 'Indians', 'Mariners', 'Marlins', 'Mets',
#        'Nationals', 'Padres', 'Phillies', 'Pirates', 'Rangers', 'Rays',
#        'Red Sox', 'Reds', 'Rockies', 'Royals', 'Tigers', 'Twins', 'White Sox',
#        'Yankees'],
#       dtype='object', name='Team')

# %%
len(mlb_teams)

# %%
new_num_teams = len(mlb_teams)
new_num_teams
# Out:
# 26

# %%
teams_
# Out:
#               WLdiff
# Team
# Rays              30
# Dodgers           50
# Twins             40
# Astros            52
# Nationals         24
# Indians           24
# Mets              10
# Athletics         32
# Reds             -12
# Yankees           44
# Cubs               6
# Red Sox            6
# Cardinals         20
# Padres           -22
# Rangers           -6
# Diamondbacks       8
# Brewers           16
# Braves            32
# White Sox        -17
# Tigers           -67
# Blue Jays        -28
# Pirates          -24
# Phillies           0
# Royals           -44
# Giants            -8
# Rockies          -20
# Marlins          -48
# Mariners         -26
# Angels           -18
# Orioles          -54

# %% [markdown]
# We started off with 30 teams with our batter, and now we're down to 26 for pitchers. What happened? Probably because we did not get all the pitchers from `fangraphs`. Let's hack around this and reduce the number of teams in our batters lists.

# %%
teams4 = teams_.reindex(mlb_teams)
teams4
# Out:
#               WLdiff
# Team
# Astros            52
# Athletics         32
# Braves            32
# Cardinals         20
# Cubs               6
# Diamondbacks       8
# Dodgers           50
# Giants            -8
# Indians           24
# Mariners         -26
# Marlins          -48
# Mets              10
# Nationals         24
# Padres           -22
# Phillies           0
# Pirates          -24
# Rangers           -6
# Rays              30
# Red Sox            6
# Reds             -12
# Rockies          -20
# Royals           -44
# Tigers           -67
# Twins             40
# White Sox        -17
# Yankees           44

# %%
teams4.values
# Out:
# array([[ 52],
#        [ 32],
#        [ 32],
#        [ 20],
#        [  6],
#        [  8],
#        [ 50],
#        [ -8],
#        [ 24],
#        [-26],
#        [-48],
#        [ 10],
#        [ 24],
#        [-22],
#        [  0],
#        [-24],
#        [ -6],
#        [ 30],
#        [  6],
#        [-12],
#        [-20],
#        [-44],
#        [-67],
#        [ 40],
#        [-17],
#        [ 44]])

# %% [markdown]
# We create new `wars2` and `opss2` factors to reflect our team reduction:

# %%
wars2 = wars.reindex(mlb_teams)
wars2
# Out:
# Team
# Astros          26.9
# Athletics       17.9
# Braves          20.6
# Cardinals       14.8
# Cubs            17.7
# Diamondbacks    15.3
# Dodgers         22.3
# Giants           2.9
# Indians         13.2
# Mariners         1.6
# Marlins          6.3
# Mets            17.2
# Nationals       20.1
# Padres           2.7
# Phillies        16.5
# Pirates         13.4
# Rangers          5.3
# Rays            11.9
# Red Sox         29.4
# Reds             6.8
# Rockies         14.3
# Royals          10.8
# Tigers          -0.3
# Twins           13.9
# White Sox       15.3
# Yankees         14.3
# Name: WARs, dtype: float64

# %%
nwars2 = nwars.reindex(mlb_teams)
nwars2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-520-8bb37506b768> in <module>()
# ----> 1 nwars2 = list(nwars).reindex(mlb_teams)
#       2 nwars2
#
# AttributeError: 'list' object has no attribute 'reindex'

# %%
opss2 = opss.reindex(mlb_teams)
opss2
# Out:
# Team
# Astros          5.379
# Athletics       4.026
# Braves          4.320
# Cardinals       3.927
# Cubs            4.317
# Diamondbacks    4.116
# Dodgers         4.500
# Giants          2.158
# Indians         3.285
# Mariners        2.185
# Marlins         2.256
# Mets            4.235
# Nationals       4.347
# Padres          1.531
# Phillies        4.005
# Pirates         4.964
# Rangers         3.112
# Rays            3.272
# Red Sox         6.019
# Reds            2.423
# Rockies         3.598
# Royals          3.345
# Tigers          0.744
# Twins           3.527
# White Sox       4.768
# Yankees         3.435
# Name: OPS, dtype: float64

# %% [markdown]
# ## Building a Bayesian Model: The Likelihood
#
# Ok, we have what we think (if our model is correct) **team priors** for **attack** and **defense** in baseball. Now let's specity our likelihood function in `pymc3`.
#
# We know that whenever we have a small number of data point (about 30 or less), the [t-distribution](https://en.wikipedia.org/wiki/Student%27s_t-distribution) gives better results than the normal distribution.
#
# The **half-t distribution** (also denoted **folded-t**) is derived from the t-distribution by taking the absolute values of variates. Since we already know the sign of `att` and `def` parameters, we don't want any negative signs. I will use the half student-t distribution to model standard deviations, but I will start my model building with normal distributions for the priors. If I get bad results, I may have to come back here and replace with student-t's instead.
#
# Since we have a linear model for log$\theta$, we have a *slope-intercept* formula: $y = mx + b$ where $m$ is the slope or the consistent change between $x$ and $y$, and $b$ is the y-intercept (intercepts the y-axis at $y = b$). It is the expected mean value of $y$ when $x = 0$.

# %% [markdown]
# # Model 1: A loose model
#
# A log-linear model with loose normal pdf priors where the log of the Poisson paramater is a linear combination of the priors (plus a bias).
#
# To see if our offense and defense factors are appropriate for the model, run a trace and see if the posteriors redistribute the means or if they stay a the same positions.
#
# We'll specify a full model, and then immediately simplify it.
#
# Here's the ***full*** model in `pymc3` (we ***won't*** run this):

# %%
num_teams

# %%
batters = range(0, 5)
pitchers = range(0, 5)

# %%
import pymc3 as pm, theano.tensor as tt

with pm.Model() as model:
    # GLOBAL model priors: standard deviation and intercept.
    # We are saying that the standard deviation and intercept priors of each
    # team's att and def parameters stem from the same folded-t distribution.
    # Note use of student-t because we only have 30 teams, low number.
    # Note mean and standard deviation for our priors, picked from a hat like a rabbit!
    sd_att = pm.HalfStudentT('sd_att', nu=3, sd=2.5)
    sd_def = pm.HalfStudentT('sd_def', nu=3, sd=2.5)
    intercept = pm.Flat('intercept') #no idea

    # TEAM-specific model parameters. There are five (att1s_star, att2s_star) tuples per team (one for each top-5 batter),
    # and five (def1s_star, def2s_star) tuples per team (one for each top-5 pitcher). Thus, 20 priors per team! We have 30
    # teams, so that's 600 parameters for our model!!
    # Note use of normal distribution because we assume we have a lot of data per team
    att1s_star = pm.Normal("att1s_star", mu=wars2, sd=sd_att, shape=num_teams * len(batters))
    att2s_star = pm.Normal("att2s_star", mu=opss2, sd=sd_att, shape=num_teams * len(batters))
    def1s_star = pm.Normal("def1s_star", mu=babips sd=sd_def, shape=num_teams * len(pitchers))
    def2s_star = pm.Normal("def2s_star", mu=fips, sd=sd_def, shape=num_teams * len(pitchers))

    # To allow samples of expressions to be saved, we need to wrap them in pymc3 Deterministic objects
    # We save these parameters for later exploration.
    att1s = pm.Deterministic('att1s', att1s_star - tt.mean(att1s_star))
    att2s = pm.Deterministic('att2s', att2s_star - tt.mean(att2s_star))
    def1s = pm.Deterministic('def1s', def1s_star - tt.mean(def1s_star))
    def2s = pm.Deterministic('def2s', def2s_star - tt.mean(def2s_star))
    
    # Assume exponential search on theta and away_theta. We're relying on theano. No idea what to do when theano goes away..
    theta = tt.exp(intercept + 
                   att1s[mlb_teams_by_rbis_index][batters] + 
                   att1s[mlb_teams_by_rbis_index][batters] + 
                   def1s[mlb_teams_by_rbis_index][pitchers] + 
                   def2s[mlb_teams_by_rbis_index][pitchers])  

    # likelihood of observed data, Poisson distribution for count data
    wins = pm.Poisson('wins', mu=theta, observed=observed_wins_losses)

# %%
num_teams

# %%
mlb_teams_by_rbis_index

# %%
observed_wins_losses

# %% [markdown]
# Here's our ***simplified*** model:

# %%
len(wars2), len(opss2), len(babips), len(fips), new_num_teams
# Out:
# (26, 26, 26, 26, 26)

# %%
mlb_teams_by_rbis_index_2 = range(0, 26)
mlb_teams_by_rbis_index_2
# Out:
# range(0, 26)

# %%
import pymc3 as pm, theano.tensor as tt

with pm.Model() as model:
    # GLOBAL model priors: standard deviation and intercept.
    # We are saying that the standard deviation and intercept priors of each
    # team's att and def parameters stem from the same folded-t distribution.
    # Note use of student-t because we only have 30 teams, low number.
    # Note mean and standard deviation for our priors, picked from a hat like a rabbit!
    sd_att = pm.HalfStudentT('sd_att', nu=3, sd=2.5)
    sd_def = pm.HalfStudentT('sd_def', nu=3, sd=2.5)
    intercept = pm.Flat('intercept') #no idea

    # TEAM-specific model parameters. There is one (att1s_star, att2s_star) tuple per team,
    # and one (def1s_star, def2s_star) tuple per team. Thus, 4 priors per team! We have 30
    # teams, so that's 120 parameters for our model!!
    # Note use of normal distribution because we assume we have a lot of data per team
    att1s_star = pm.Normal("att1s_star", mu=wars2, sd=sd_att, shape=new_num_teams)
    att2s_star = pm.Normal("att2s_star", mu=opss2, sd=sd_att, shape=new_num_teams)
    def1s_star = pm.Normal("def1s_star", mu=babips, sd=sd_def, shape=new_num_teams)
    def2s_star = pm.Normal("def2s_star", mu=fips, sd=sd_def, shape=new_num_teams)

    # To allow samples of expressions to be saved, we need to wrap them in pymc3 Deterministic objects
    # We save these parameters for later exploration.
    att1s = pm.Deterministic('att1s', att1s_star - tt.mean(att1s_star))
    att2s = pm.Deterministic('att2s', att2s_star - tt.mean(att2s_star))
    def1s = pm.Deterministic('def1s', def1s_star - tt.mean(def1s_star))
    def2s = pm.Deterministic('def2s', def2s_star - tt.mean(def2s_star))
    
    # Assume exponential search on theta and away_theta. We're relying on theano. No idea what to do when theano goes away..
    theta = tt.exp(intercept + 
                   att1s[mlb_teams_by_rbis_index_2] + 
                   att1s[mlb_teams_by_rbis_index_2] + 
                   def1s[mlb_teams_by_rbis_index_2] + 
                   def2s[mlb_teams_by_rbis_index_2])  

    # likelihood of observed data, Poisson distribution for count data
    wins = pm.Poisson('wins', mu=theta, observed=teams4.values)

# %% [markdown]
# So let's think this through. We have `att1s_star`, `att2s_star`, `def1s_star`, `def1s_star` priors that are **very loosely specified** (just initial mean of our offense and defense point estimates) offense and defense ***normal pdfs***. If these priors are good models, then our posteriors should reflect this. That means our distributions will sharpen (smaller standard deviations), but the means should not redistribute as we converge in our simulation. If they do, that could mean that our model parameter choice may be overly ***simplistic***.

# %% [markdown]
# </br >
# <center>
# <img src="ipynb.images/allright.gif" width=300 />
# </center>
#
# Allright allright allright! We have our model.
#
# A *trace* is a MCMC sampling of your **posterior** probability distribution: the shape of your priors after matching them to our observations of the 2019 season. This yields the parameters for our model (`att` and `def` per team, for a log-linear model consisting of the top-5 batters and the top-5 pitchers) that are ***most likely to fit our observations***.
#
# We won't specify an algorithm. PyMC3 will most likely choose NUTS. Our parameter space is 600-dimensional! How long do you think this trace will take? Will it fry my kernel?
#
# </br >
# <center>
# <img src="ipynb.images/dastardly.png" width=300 />
# </center>

# %%
with model:
    trace = pm.sample(1000, tune=1000, cores=2)
    pm.traceplot(trace)

# %% [markdown]
# # Model 2: A tighter model
#
# We model a ***team*** **power** stochastic variable $\lambda$ as a linear model of our offense and defense parameters:
#
# $$\lambda_{i} = \alpha_{0i} + \alpha_{1i}(wars)_{i} + \alpha_{2i}(ops)_{i}  + \beta_{1i}(babips)_{i} + \beta_{2i}(fips)_{i}$$
#
# Priors are now $\alpha_{0i}$, $\alpha_{1i}$, $\alpha_{2i}$, $\beta_{1i}$, $\beta_{2i}$, for $i$ in 0, .., $N$ teams, expressed as pdfs.
#
# And we model our likelihood as a poisson distribution based on win/loss differentials:
#
# $$\text{likelihood}_t = \text{Poisson}(\lambda_t,τ_t)$$
#
# We then use PyMC3 Generalized Linear Model (GLM) syntax ([patsy](https://patsy.readthedocs.io/en/latest/formulas.html) style). It's this expression, which says that we want win/loss differential to be a linear combination of the other variables: `win-loss ~ wars + ops + babips + fips`.

# %%
with pm.Model() as glm_model:
    pm.glm.GLM.from_formula('WL ~ WARs + OPS + BABIP% + FIPs',
                            data,
                            family=pm.glm.families.Poisson())
    trace = pm.sample(1000, tune=1000, init='adapt_diag')
# Out:
# Traceback (most recent call last):
#
#   File "d:\Anaconda3.5.1\lib\site-packages\IPython\core\interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-524-63a41808d6bc>", line 4, in <module>
#     family=pm.glm.families.Poisson())
#
#   File "d:\Anaconda3.5.1\lib\site-packages\pymc3\glm\linear.py", line 145, in from_formula
#     y, x = patsy.dmatrices(formula, data)
#
#   File "d:\Anaconda3.5.1\lib\site-packages\patsy\highlevel.py", line 310, in dmatrices
#     NA_action, return_type)
#
#   File "d:\Anaconda3.5.1\lib\site-packages\patsy\highlevel.py", line 165, in _do_highlevel_design
#     NA_action)
#
#   File "d:\Anaconda3.5.1\lib\site-packages\patsy\highlevel.py", line 70, in _try_incr_builders
#     NA_action)
#
#   File "d:\Anaconda3.5.1\lib\site-packages\patsy\build.py", line 689, in design_matrix_builders
#     factor_states = _factors_memorize(all_factors, data_iter_maker, eval_env)
#
#   File "d:\Anaconda3.5.1\lib\site-packages\patsy\build.py", line 354, in _factors_memorize
#     which_pass = factor.memorize_passes_needed(state, eval_env)
#
#   File "d:\Anaconda3.5.1\lib\site-packages\patsy\eval.py", line 474, in memorize_passes_needed
#     subset_names = [name for name in ast_names(self.code)
#
#   File "d:\Anaconda3.5.1\lib\site-packages\patsy\eval.py", line 474, in <listcomp>
#     subset_names = [name for name in ast_names(self.code)
#
#   File "d:\Anaconda3.5.1\lib\site-packages\patsy\eval.py", line 105, in ast_names
#     for node in ast.walk(ast.parse(code)):
#
#   File "d:\Anaconda3.5.1\lib\ast.py", line 35, in parse
#     return compile(source, filename, mode, PyCF_ONLY_AST)
#
#   File "<unknown>", line 1
#     BABIP %
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# So now we need to create our `data` dataframe:

# %%
data = pd.concat([wars2, opss2, babips, fips], axis=1)
data
# Out:
#               WARs    OPS    BABIP%      FIPs
# Team
# Astros        26.9  5.379  0.820000  3.393333
# Athletics     17.9  4.026  0.766500  4.990000
# Braves        20.6  4.320  0.769333  4.143333
# Cardinals     14.8  3.927  0.779250  4.190000
# Cubs          17.7  4.317  0.717000  4.050000
# Diamondbacks  15.3  4.116  0.741000  4.170000
# Dodgers       22.3  4.500  0.790667  3.396667
# Giants         2.9  2.158  0.743500  4.665000
# Indians       13.2  3.285  0.774000  3.230000
# Mariners       1.6  2.185  0.692000  5.110000
# Marlins        6.3  2.256  0.738000  5.170000
# Mets          17.2  4.235  0.740333  3.666667
# Nationals     20.1  4.347  0.768500  3.685000
# Padres         2.7  1.531  0.730000  4.360000
# Phillies      16.5  4.005  0.753500  4.290000
# Pirates       13.4  4.964  0.632000  4.310000
# Rangers        5.3  3.112  0.773500  4.225000
# Rays          11.9  3.272  0.753000  3.280000
# Red Sox       29.4  6.019  0.717000  4.620000
# Reds           6.8  2.423  0.780333  3.810000
# Rockies       14.3  3.598  0.681000  3.540000
# Royals        10.8  3.345  0.712500  4.785000
# Tigers        -0.3  0.744  0.744000  3.880000
# Twins         13.9  3.527  0.705500  4.505000
# White Sox     15.3  4.768  0.732333  4.613333
# Yankees       14.3  3.435  0.704000  4.290000

# %% [markdown]
# oops.. need to replace `wars` with `nwars`!
#
# Also, we need to tack on the win/loss column (with reduced team dataset):

# %%
data['WL'] = teams4.values
data
# Out:
#               WARs    OPS    BABIP%      FIPs  WL
# Team
# Astros        26.9  5.379  0.820000  3.393333  52
# Athletics     17.9  4.026  0.766500  4.990000  32
# Braves        20.6  4.320  0.769333  4.143333  32
# Cardinals     14.8  3.927  0.779250  4.190000  20
# Cubs          17.7  4.317  0.717000  4.050000   6
# Diamondbacks  15.3  4.116  0.741000  4.170000   8
# Dodgers       22.3  4.500  0.790667  3.396667  50
# Giants         2.9  2.158  0.743500  4.665000  -8
# Indians       13.2  3.285  0.774000  3.230000  24
# Mariners       1.6  2.185  0.692000  5.110000 -26
# Marlins        6.3  2.256  0.738000  5.170000 -48
# Mets          17.2  4.235  0.740333  3.666667  10
# Nationals     20.1  4.347  0.768500  3.685000  24
# Padres         2.7  1.531  0.730000  4.360000 -22
# Phillies      16.5  4.005  0.753500  4.290000   0
# Pirates       13.4  4.964  0.632000  4.310000 -24
# Rangers        5.3  3.112  0.773500  4.225000  -6
# Rays          11.9  3.272  0.753000  3.280000  30
# Red Sox       29.4  6.019  0.717000  4.620000   6
# Reds           6.8  2.423  0.780333  3.810000 -12
# Rockies       14.3  3.598  0.681000  3.540000 -20
# Royals        10.8  3.345  0.712500  4.785000 -44
# Tigers        -0.3  0.744  0.744000  3.880000 -67
# Twins         13.9  3.527  0.705500  4.505000  40
# White Sox     15.3  4.768  0.732333  4.613333 -17
# Yankees       14.3  3.435  0.704000  4.290000  44

# %% [markdown]
# *etc* :-)
